# %% [markdown]
# # IMPORT MODULES

# %%
import pandas as pd

# %% [markdown]
# # CATEGORIES CLASS

# %%
class Categories:
 
    def __init__(self, _name, _index):
        self.name = _name
        self.index = _index
        self.prob = 0
        self.entropy = 0

# %% [markdown]
# # FEATURES CLASS

# %%
class Features:
    def __init__(self, _name, _feat_type):
        self.name = _name
        self.feat_type = _feat_type
        self.num_cat = 0
        self.categories = dict()
        self.entropy = 0
        self.std_entropy = 0
        self.reliability = 0
        self.weight = 0
        self.distances = dict()

# %% [markdown]
# # ORDINAL DATA

# %%
def read_ord(data):
    try:
        ordinal_categories = pd.read_csv(data,header=None,index_col=0)
    except ImportError:
        print('Error Importing Ordinal Data')

    features = dict()
    
    for feat in ordinal_categories.index:
        feat_instance = Features(feat,'ordinal')
        
        cat_names = ordinal_categories.loc[feat,ordinal_categories.loc[feat,:].notnull()].tolist()
        feat_instance.num_cat = len(cat_names)
        
        for _index, _name in enumerate(cat_names):
            feat_instance.categories[_name] = Categories(_name, _index)
           
        features[feat] = feat_instance
        
    return features

# %% [markdown]
# # NOMINAL DATA

# %%
def read_norm(data):
    try:
        nominal_categories = pd.read_csv(data,header=None,index_col=0)
    except ImportError:
        print('Error Importing Nominal Data')

    features = dict()
    
    for feat in nominal_categories.index:
        feat_instance = Features(feat,'nominal')
        
        cat_names = nominal_categories.loc[feat,nominal_categories.loc[feat,:].notnull()].tolist()
        feat_instance.num_cat = len(cat_names)
        
        for _index, _name in enumerate(cat_names):
            feat_instance.categories[_name] = Categories(_name, _index)
           
        features[feat] = feat_instance
        
    return features

# %% [markdown]
# # TEST READ ORD AND NOM

# %%
feat = read_ord('Preprocessed_Ordinal.csv')

# %%
for f in feat.keys():
    print('name:',f)
    print('type:',feat[f].feat_type)
    print('num_cat:',feat[f].num_cat)
    print()
    for cat in feat[f].categories.keys():
        print('    index:',feat[f].categories[cat].index)
        print('    name:',feat[f].categories[cat].name)
        print()
    print()
# Out:
# name: achievingends_quality
# type: ordinal
# num_cat: 3
#
#     index: 0
#     name: poor
#
#     index: 1
#     name: medium
#
#     index: 2
#     name: good
#
#
# name: anger_quality
# type: ordinal
# num_cat: 3
#
#     index: 0
#     name: poor
#
#     index: 1
#     name: medium
#
#     index: 2
#     name: good
#
#
# name: anger_speed
# type: ordinal
# num_cat: 4
#
#     index: 0
#     name: slowly
#
#     index: 1
#     name: moderately
#
#     index: 2
#     name: quickly
#
#     index: 3
#     name: variably
#
#
# name: appetite_amount
# type: ordinal
# num_cat: 4
#
#     index: 0
#     name: low
#
#     index: 1
#     name: medium
#
#     index: 2
#     name: high
#
#     index: 3
#     name: variable
#
#
# name: bladder_amount
# type: ordinal
# num_cat: 4
#
#     index: 0
#     name: low
#
#     index: 1
#     name: medium
#
#     index: 2
#     name: high
#
#     index: 3
#     name: variable
#
#
# name: body_odour
# type: ordinal
# num_cat: 3
#
#     index: 0
#     name: veryless
#
#     index: 1
#     name: mild
#
#     index: 2
#     name: strong
#
#
# name: bodybuild_size
# type: ordinal
# num_cat: 3
#
#     index: 0
#     name: weaklydeveloped
#
#     index: 1
#     name: moderatelydeveloped
#
#     index: 2
#     name: welldeveloped
#
#
# name: bodyframe_breadth
# type: ordinal
# num_cat: 3
#
#     index: 0
#     name: thin/narrow
#
#     index: 1
#     name: medium
#
#     index: 2
#     name: broad
#
#
# name: bodyframe_length
# type: ordinal
# num_cat: 3
#
#     index: 0
#     name: tooshort/toolong
#
#     index: 1
#     name: medium
#
#     index: 2
#     name: long
#
#
# name: bodyhair_color
# type: ordinal
# num_cat: 6
#
#     index: 0
#     name: black
#
#     index: 1
#     name: darkbrown
#
#     index: 2
#     name: lightbrown
#
#     index: 3
#     name: dusky
#
#     index: 4
#     name: blonde
#
#     index: 5
#     name: copper
#
#
# name: bodytemp_amount
# type: ordinal
# num_cat: 4
#
#     index: 0
#     name: low
#
#     index: 1
#     name: medium
#
#     index: 2
#     name: high
#
#     index: 3
#     name: variable
#
#
# name: bowel_tendency
# type: ordinal
# num_cat: 3
#
#     index: 0
#     name: constipation
#
#     index: 1
#     name: none
#
#     index: 2
#     name: loosemotion
#
#
# name: chest_breadth
# type: ordinal
# num_cat: 3
#
#     index: 0
#     name: thin/narrow
#
#     index: 1
#     name: medium
#
#     index: 2
#     name: broad
#
#
# name: digestive_amount
# type: ordinal
# num_cat: 4
#
#     index: 0
#     name: low
#
#     index: 1
#     name: medium
#
#     index: 2
#     name: high
#
#     index: 3
#     name: variable
#
#
# name: dreams_amount
# type: ordinal
# num_cat: 4
#
#     index: 0
#     name: low
#
#     index: 1
#     name: medium
#
#     index: 2
#     name: high
#
#     index: 3
#     name: variable
#
#
# name: execution_quality
# type: ordinal
# num_cat: 3
#
#     index: 0
#     name: poor
#
#     index: 1
#     name: medium
#
#     index: 2
#     name: good
#
#
# name: eye_size
# type: ordinal
# num_cat: 3
#
#     index: 0
#     name: weaklydeveloped
#
#     index: 1
#     name: moderatelydeveloped
#
#     index: 2
#     name: welldeveloped
#
#
# name: eyebrow_size
# type: ordinal
# num_cat: 3
#
#     index: 0
#     name: small
#
#     index: 1
#     name: medium
#
#     index: 2
#     name: large
#
#
# name: eyebrows_movements
# type: ordinal
# num_cat: 3
#
#     index: 0
#     name: less
#
#     index: 1
#     name: moderate
#
#     index: 2
#     name: high/excessive
#
#
# name: eyelash_size
# type: ordinal
# num_cat: 3
#
#     index: 0
#     name: small
#
#     index: 1
#     name: medium
#
#     index: 2
#     name: large
#
#
# name: eyes_movements
# type: ordinal
# num_cat: 3
#
#     index: 0
#     name: less
#
#     index: 1
#     name: moderate
#
#     index: 2
#     name: high/excessive
#
#
# name: face_size
# type: ordinal
# num_cat: 3
#
#     index: 0
#     name: weaklydeveloped
#
#     index: 1
#     name: moderatelydeveloped
#
#     index: 2
#     name: welldeveloped
#
#
# name: faith_quality
# type: ordinal
# num_cat: 3
#
#     index: 0
#     name: poor
#
#     index: 1
#     name: medium
#
#     index: 2
#     name: good
#
#
# name: forehead_breadth
# type: ordinal
# num_cat: 3
#
#     index: 0
#     name: thin/narrow
#
#     index: 1
#     name: medium
#
#     index: 2
#     name: broad
#
#
# name: forehead_length
# type: ordinal
# num_cat: 3
#
#     index: 0
#     name: tooshort/toolong
#
#     index: 1
#     name: medium
#
#     index: 2
#     name: long
#
#
# name: forgetfulness_speed
# type: ordinal
# num_cat: 4
#
#     index: 0
#     name: slowly
#
#     index: 1
#     name: moderately
#
#     index: 2
#     name: quickly
#
#     index: 3
#     name: variably
#
#
# name: forgiveness_quality
# type: ordinal
# num_cat: 3
#
#     index: 0
#     name: poor
#
#     index: 1
#     name: medium
#
#     index: 2
#     name: good
#
#
# name: generosity_quality
# type: ordinal
# num_cat: 3
#
#     index: 0
#     name: poor
#
#     index: 1
#     name: medium
#
#     index: 2
#     name: good
#
#
# name: hair_growth
# type: ordinal
# num_cat: 4
#
#     index: 0
#     name: dense
#
#     index: 1
#     name: scanty
#
#     index: 2
#     name: moderate
#
#     index: 3
#     name: bald
#
#
# name: hair_look
# type: ordinal
# num_cat: 3
#
#     index: 0
#     name: straight
#
#     index: 1
#     name: wavy
#
#     index: 2
#     name: fizzy/curly
#
#
# name: hair_type
# type: ordinal
# num_cat: 9
#
#     index: 0
#     name: thick
#
#     index: 1
#     name: thin
#
#     index: 2
#     name: coarse
#
#     index: 3
#     name: hard
#
#     index: 4
#     name: smooth
#
#     index: 5
#     name: soft
#
#     index: 6
#     name: straight
#
#     index: 7
#     name: wavy
#
#     index: 8
#     name: fizzy/curly
#
#
# name: hands_length
# type: ordinal
# num_cat: 3
#
#     index: 0
#     name: tooshort/toolong
#
#     index: 1
#     name: medium
#
#     index: 2
#     name: long
#
#
# name: hands_movements
# type: ordinal
# num_cat: 3
#
#     index: 0
#     name: less
#
#     index: 1
#     name: moderate
#
#     index: 2
#     name: high/excessive
#
#
# name: head_movements
# type: ordinal
# num_cat: 3
#
#     index: 0
#     name: less
#
#     index: 1
#     name: moderate
#
#     index: 2
#     name: high/excessive
#
#
# name: healing_power
# type: ordinal
# num_cat: 3
#
#     index: 0
#     name: grade1
#
#     index: 1
#     name: grade2
#
#     index: 2
#     name: grade3
#
#
# name: healthproblem_in_temp
# type: ordinal
# num_cat: 4
#
#     index: 0
#     name: none
#
#     index: 1
#     name: cold
#
#     index: 2
#     name: warm
#
#     index: 3
#     name: both
#
#
# name: initiation_speed
# type: ordinal
# num_cat: 4
#
#     index: 0
#     name: slowly
#
#     index: 1
#     name: moderately
#
#     index: 2
#     name: quickly
#
#     index: 3
#     name: variably
#
#
# name: irritability_speed
# type: ordinal
# num_cat: 4
#
#     index: 0
#     name: slowly
#
#     index: 1
#     name: moderately
#
#     index: 2
#     name: quickly
#
#     index: 3
#     name: variably
#
#
# name: jaw_movements
# type: ordinal
# num_cat: 3
#
#     index: 0
#     name: less
#
#     index: 1
#     name: moderate
#
#     index: 2
#     name: high/excessive
#
#
# name: joint_size
# type: ordinal
# num_cat: 3
#
#     index: 0
#     name: weaklydeveloped
#
#     index: 1
#     name: moderatelydeveloped
#
#     index: 2
#     name: welldeveloped
#
#
# name: leg_length
# type: ordinal
# num_cat: 3
#
#     index: 0
#     name: tooshort/toolong
#
#     index: 1
#     name: medium
#
#     index: 2
#     name: long
#
#
# name: legs_movements
# type: ordinal
# num_cat: 3
#
#     index: 0
#     name: less
#
#     index: 1
#     name: moderate
#
#     index: 2
#     name: high/excessive
#
#
# name: lip_size
# type: ordinal
# num_cat: 3
#
#     index: 0
#     name: small
#
#     index: 1
#     name: medium
#
#     index: 2
#     name: large
#
#
# name: lips_movements
# type: ordinal
# num_cat: 3
#
#     index: 0
#     name: less
#
#     index: 1
#     name: moderate
#
#     index: 2
#     name: high/excessive
#
#
# name: makingfriends_speed
# type: ordinal
# num_cat: 4
#
#     index: 0
#     name: slowly
#
#     index: 1
#     name: moderately
#
#     index: 2
#     name: quickly
#
#     index: 3
#     name: variably
#
#
# name: memorizing_speed
# type: ordinal
# num_cat: 4
#
#     index: 0
#     name: slowly
#
#     index: 1
#     name: moderately
#
#     index: 2
#     name: quickly
#
#     index: 3
#     name: variably
#
#
# name: memory_auditory
# type: ordinal
# num_cat: 2
#
#     index: 0
#     name: poor
#
#     index: 1
#     name: good
#
#
# name: memory_gustatory
# type: ordinal
# num_cat: 2
#
#     index: 0
#     name: poor
#
#     index: 1
#     name: good
#
#
# name: memory_olfactory
# type: ordinal
# num_cat: 2
#
#     index: 0
#     name: poor
#
#     index: 1
#     name: good
#
#
# name: memory_tactile
# type: ordinal
# num_cat: 2
#
#     index: 0
#     name: poor
#
#     index: 1
#     name: good
#
#
# name: memory_visual
# type: ordinal
# num_cat: 2
#
#     index: 0
#     name: poor
#
#     index: 1
#     name: good
#
#
# name: mental_power
# type: ordinal
# num_cat: 3
#
#     index: 0
#     name: grade1
#
#     index: 1
#     name: grade2
#
#     index: 2
#     name: grade3
#
#
# name: nails_length
# type: ordinal
# num_cat: 3
#
#     index: 0
#     name: tooshort/toolong
#
#     index: 1
#     name: medium
#
#     index: 2
#     name: long
#
#
# name: perspiration_amount
# type: ordinal
# num_cat: 4
#
#     index: 0
#     name: low
#
#     index: 1
#     name: medium
#
#     index: 2
#     name: high
#
#     index: 3
#     name: variable
#
#
# name: physical_power
# type: ordinal
# num_cat: 3
#
#     index: 0
#     name: grade1
#
#     index: 1
#     name: grade2
#
#     index: 2
#     name: grade3
#
#
# name: planning_quality
# type: ordinal
# num_cat: 3
#
#     index: 0
#     name: poor
#
#     index: 1
#     name: medium
#
#     index: 2
#     name: good
#
#
# name: recalling_speed
# type: ordinal
# num_cat: 4
#
#     index: 0
#     name: slowly
#
#     index: 1
#     name: moderately
#
#     index: 2
#     name: quickly
#
#     index: 3
#     name: variably
#
#
# name: resistance_power
# type: ordinal
# num_cat: 3
#
#     index: 0
#     name: grade1
#
#     index: 1
#     name: grade2
#
#     index: 2
#     name: grade3
#
#
# name: retaining_quality
# type: ordinal
# num_cat: 3
#
#     index: 0
#     name: poor
#
#     index: 1
#     name: medium
#
#     index: 2
#     name: good
#
#
# name: retainingfriends_quality
# type: ordinal
# num_cat: 3
#
#     index: 0
#     name: poor
#
#     index: 1
#     name: medium
#
#     index: 2
#     name: good
#
#
# name: shoulder_breadth
# type: ordinal
# num_cat: 3
#
#     index: 0
#     name: thin/narrow
#
#     index: 1
#     name: medium
#
#     index: 2
#     name: broad
#
#
# name: shoulder_movements
# type: ordinal
# num_cat: 3
#
#     index: 0
#     name: less
#
#     index: 1
#     name: moderate
#
#     index: 2
#     name: high/excessive
#
#
# name: skin_type
# type: ordinal
# num_cat: 7
#
#     index: 0
#     name: thick
#
#     index: 1
#     name: thin
#
#     index: 2
#     name: dry
#
#     index: 3
#     name: oily
#
#     index: 4
#     name: normal
#
#     index: 5
#     name: seasonal/variable
#
#     index: 6
#     name: hard
#
#
# name: sleep_amount
# type: ordinal
# num_cat: 4
#
#     index: 0
#     name: low
#
#     index: 1
#     name: medium
#
#     index: 2
#     name: high
#
#     index: 3
#     name: variable
#
#
# name: speaking_amount
# type: ordinal
# num_cat: 3
#
#     index: 0
#     name: less
#
#     index: 1
#     name: moderate
#
#     index: 2
#     name: excessive
#
#
# name: speaking_speed
# type: ordinal
# num_cat: 4
#
#     index: 0
#     name: slow
#
#     index: 1
#     name: medium
#
#     index: 2
#     name: quick
#
#     index: 3
#     name: variable
#
#
# name: stool_consistency
# type: ordinal
# num_cat: 3
#
#     index: 0
#     name: loose/soft/semisolid
#
#     index: 1
#     name: medium
#
#     index: 2
#     name: hard
#
#
# name: teeth_color
# type: ordinal
# num_cat: 3
#
#     index: 0
#     name: milkywhite
#
#     index: 1
#     name: yellowish
#
#     index: 2
#     name: dull/blackish
#
#
# name: teeth_size
# type: ordinal
# num_cat: 4
#
#     index: 0
#     name: toosmall
#
#     index: 1
#     name: medium
#
#     index: 2
#     name: large
#
#     index: 3
#     name: toolarge
#
#
# name: tongue_movements
# type: ordinal
# num_cat: 3
#
#     index: 0
#     name: less
#
#     index: 1
#     name: moderate
#
#     index: 2
#     name: high/excessive
#
#
# name: walking_amount
# type: ordinal
# num_cat: 3
#
#     index: 0
#     name: less
#
#     index: 1
#     name: moderate
#
#     index: 2
#     name: high/excessive
#
#
# name: walking_speed
# type: ordinal
# num_cat: 4
#
#     index: 0
#     name: slow
#
#     index: 1
#     name: medium
#
#     index: 2
#     name: quick/fast/brisk
#
#     index: 3
#     name: variable
#
#
# name: walking_steps
# type: ordinal
# num_cat: 3
#
#     index: 0
#     name: small
#
#     index: 1
#     name: medium
#
#     index: 2
#     name: large
#
#
# name: working_speed
# type: ordinal
# num_cat: 4
#
#     index: 0
#     name: slow
#
#     index: 1
#     name: medium
#
#     index: 2
#     name: quick/fast/brisk
#
#     index: 3
#     name: variable

# %% [markdown]
# ## Verdict: Working
#
# Can also try running for nominal here if you want.

# %% [markdown]
# # READ POPULATION

# %%
 df = pd.read_csv('Preprocessed_Dataset.csv', index_col=0)

# %%
df.drop('prakriti',axis=1,inplace=True)

# run this only once otherwise you'll get errors

# %%
df.head()
# Out:
#            achievingends_quality anger_quality anger_speed appetite_amount  \
# sampleid
# V091206280                  good        medium      slowly          medium
# V091201522                  poor          good     quickly          medium
# V091206079                  poor          good      slowly          medium
# V091202231                medium        medium    variably            high
# V091209882                  poor          poor     quickly        variable
#
#            appetite_frequency bladder_amount bladder_frequency body_odour  \
# sampleid
# V091206280            regular         medium           regular       mild
# V091201522            regular         medium           regular   veryless
# V091206079            regular           high           regular     strong
# V091202231            regular         medium           regular     strong
# V091209882          irregular         medium           regular       mild
#
#                  bodybuild_size bodyframe_breadth  ...  \
# sampleid                                           ...
# V091206280  moderatelydeveloped            medium  ...
# V091201522        welldeveloped             broad  ...
# V091206079      weaklydeveloped       thin/narrow  ...
# V091202231  moderatelydeveloped            medium  ...
# V091209882  moderatelydeveloped            medium  ...
#
#                        working_quality     working_speed   working_style  \
# sampleid
# V091206280  sharp/accurate/spontaneous            medium  sharp/accurate
# V091201522               wellthoughtof              slow     firm/steady
# V091206079     wavering/easilydeviated  quick/fast/brisk        unsteady
# V091202231  sharp/accurate/spontaneous  quick/fast/brisk  sharp/accurate
# V091209882  sharp/accurate/spontaneous            medium  sharp/accurate
#
#            skin_clear skin_cracked skin_freckle skin_mark skin_mole  \
# sampleid
# V091206280        yes           no           no        no        no
# V091201522         no          yes           no        no        no
# V091206079         no           no           no       yes       yes
# V091202231         no           no           no       yes        no
# V091209882         no           no          yes       yes        no
#
#            skin_pimple skin_wrinkled
# sampleid
# V091206280          no            no
# V091201522         yes            no
# V091206079          no            no
# V091202231          no            no
# V091209882          no            no
#
# [5 rows x 143 columns]

# %%
def probability(df, features):
    for feat in features.keys():
        series = df[feat].value_counts(normalize=True,sort=False)
        for cat in series.index:
            features[feat].categories[cat].prob = series[cat]

    return features

# %%
feat = probability(df,feat)

# %%
for f in feat.keys():
    print(f)
    print(feat[f].feat_type,feat[f].num_cat)
    for cat in feat[f].categories.keys():
        print(feat[f].categories[cat].index,feat[f].categories[cat].name,feat[f].categories[cat].prob)
    print()
# Out:
# achievingends_quality
# ordinal 3
# 0 poor 0.1984126984126984
# 1 medium 0.45634920634920634
# 2 good 0.34523809523809523
#
# anger_quality
# ordinal 3
# 0 poor 0.192
# 1 medium 0.572
# 2 good 0.236
#
# anger_speed
# ordinal 4
# 0 slowly 0.18326693227091634
# 1 moderately 0.3187250996015936
# 2 quickly 0.47808764940239046
# 3 variably 0.0199203187250996
#
# appetite_amount
# ordinal 4
# 0 low 0.17391304347826086
# 1 medium 0.6521739130434783
# 2 high 0.11462450592885376
# 3 variable 0.05928853754940711
#
# bladder_amount
# ordinal 4
# 0 low 0.012195121951219513
# 1 medium 0.8780487804878049
# 2 high 0.07317073170731707
# 3 variable 0.036585365853658534
#
# body_odour
# ordinal 3
# 0 veryless 0.44621513944223107
# 1 mild 0.44621513944223107
# 2 strong 0.10756972111553785
#
# bodybuild_size
# ordinal 3
# 0 weaklydeveloped 0.2964426877470356
# 1 moderatelydeveloped 0.44664031620553357
# 2 welldeveloped 0.25691699604743085
#
# bodyframe_breadth
# ordinal 3
# 0 thin/narrow 0.3531746031746032
# 1 medium 0.39285714285714285
# 2 broad 0.25396825396825395
#
# bodyframe_length
# ordinal 3
# 0 tooshort/toolong 0.08
# 1 medium 0.712
# 2 long 0.208
#
# bodyhair_color
# ordinal 6
# 0 black 0.24206349206349206
# 1 darkbrown 0.3412698412698413
# 2 lightbrown 0.36904761904761907
# 3 dusky 0.047619047619047616
# 4 blonde 0
# 5 copper 0
#
# bodytemp_amount
# ordinal 4
# 0 low 0.2608695652173913
# 1 medium 0.4901185770750988
# 2 high 0.23715415019762845
# 3 variable 0.011857707509881422
#
# bowel_tendency
# ordinal 3
# 0 constipation 0.26693227091633465
# 1 none 0.5577689243027888
# 2 loosemotion 0.1752988047808765
#
# chest_breadth
# ordinal 3
# 0 thin/narrow 0.2619047619047619
# 1 medium 0.5238095238095238
# 2 broad 0.21428571428571427
#
# digestive_amount
# ordinal 4
# 0 low 0.16600790513833993
# 1 medium 0.616600790513834
# 2 high 0.17391304347826086
# 3 variable 0.043478260869565216
#
# dreams_amount
# ordinal 4
# 0 low 0.3466135458167331
# 1 medium 0.4820717131474104
# 2 high 0.06772908366533864
# 3 variable 0.10358565737051793
#
# execution_quality
# ordinal 3
# 0 poor 0.22310756972111553
# 1 medium 0.6175298804780877
# 2 good 0.1593625498007968
#
# eye_size
# ordinal 3
# 0 weaklydeveloped 0.233201581027668
# 1 moderatelydeveloped 0.6877470355731226
# 2 welldeveloped 0.07905138339920949
#
# eyebrow_size
# ordinal 3
# 0 small 0.031746031746031744
# 1 medium 0.8134920634920635
# 2 large 0.15476190476190477
#
# eyebrows_movements
# ordinal 3
# 0 less 0.8300395256916996
# 1 moderate 0.16205533596837945
# 2 high/excessive 0.007905138339920948
#
# eyelash_size
# ordinal 3
# 0 small 0.07905138339920949
# 1 medium 0.8893280632411067
# 2 large 0.03162055335968379
#
# eyes_movements
# ordinal 3
# 0 less 0.6007905138339921
# 1 moderate 0.3794466403162055
# 2 high/excessive 0.019762845849802372
#
# face_size
# ordinal 3
# 0 weaklydeveloped 0.15476190476190477
# 1 moderatelydeveloped 0.6984126984126984
# 2 welldeveloped 0.14682539682539683
#
# faith_quality
# ordinal 3
# 0 poor 0.264
# 1 medium 0.52
# 2 good 0.216
#
# forehead_breadth
# ordinal 3
# 0 thin/narrow 0.043824701195219126
# 1 medium 0.8884462151394422
# 2 broad 0.06772908366533864
#
# forehead_length
# ordinal 3
# 0 tooshort/toolong 0.10358565737051793
# 1 medium 0.8127490039840638
# 2 long 0.08366533864541832
#
# forgetfulness_speed
# ordinal 4
# 0 slowly 0.27380952380952384
# 1 moderately 0.42857142857142855
# 2 quickly 0.2857142857142857
# 3 variably 0.011904761904761904
#
# forgiveness_quality
# ordinal 3
# 0 poor 0.099601593625498
# 1 medium 0.5139442231075697
# 2 good 0.38645418326693226
#
# generosity_quality
# ordinal 3
# 0 poor 0.09090909090909091
# 1 medium 0.5652173913043478
# 2 good 0.3438735177865613
#
# hair_growth
# ordinal 4
# 0 dense 0.1721311475409836
# 1 scanty 0.0860655737704918
# 2 moderate 0.7418032786885246
# 3 bald 0
#
# hair_look
# ordinal 3
# 0 straight 0.7666666666666667
# 1 wavy 0.1
# 2 fizzy/curly 0.13333333333333333
#
# hair_type
# ordinal 9
# 0 thick 0.19444444444444445
# 1 thin 0.8055555555555556
# 2 coarse 0
# 3 hard 0
# 4 smooth 0
# 5 soft 0
# 6 straight 0
# 7 wavy 0
# 8 fizzy/curly 0
#
# hands_length
# ordinal 3
# 0 tooshort/toolong 0.02766798418972332
# 1 medium 0.8695652173913043
# 2 long 0.10276679841897234
#
# hands_movements
# ordinal 3
# 0 less 0.32806324110671936
# 1 moderate 0.5770750988142292
# 2 high/excessive 0.09486166007905138
#
# head_movements
# ordinal 3
# 0 less 0.746031746031746
# 1 moderate 0.20634920634920634
# 2 high/excessive 0.047619047619047616
#
# healing_power
# ordinal 3
# 0 grade1 0.08300395256916997
# 1 grade2 0.7272727272727273
# 2 grade3 0.18972332015810275
#
# healthproblem_in_temp
# ordinal 4
# 0 none 0.20242914979757085
# 1 cold 0.3967611336032389
# 2 warm 0.340080971659919
# 3 both 0.06072874493927125
#
# initiation_speed
# ordinal 4
# 0 slowly 0.08366533864541832
# 1 moderately 0.5338645418326693
# 2 quickly 0.38247011952191234
# 3 variably 0
#
# irritability_speed
# ordinal 4
# 0 slowly 0.2350597609561753
# 1 moderately 0.3386454183266932
# 2 quickly 0.41832669322709165
# 3 variably 0.00796812749003984
#
# jaw_movements
# ordinal 3
# 0 less 0.9523809523809523
# 1 moderate 0.04365079365079365
# 2 high/excessive 0.003968253968253968
#
# joint_size
# ordinal 3
# 0 weaklydeveloped 0.2
# 1 moderatelydeveloped 0.624
# 2 welldeveloped 0.176
#
# leg_length
# ordinal 3
# 0 tooshort/toolong 0.011857707509881422
# 1 medium 0.8853754940711462
# 2 long 0.10276679841897234
#
# legs_movements
# ordinal 3
# 0 less 0.444
# 1 moderate 0.512
# 2 high/excessive 0.044
#
# lip_size
# ordinal 3
# 0 small 0.12301587301587301
# 1 medium 0.8055555555555556
# 2 large 0.07142857142857142
#
# lips_movements
# ordinal 3
# 0 less 0.766798418972332
# 1 moderate 0.22529644268774704
# 2 high/excessive 0.007905138339920948
#
# makingfriends_speed
# ordinal 4
# 0 slowly 0.12301587301587301
# 1 moderately 0.6468253968253969
# 2 quickly 0.21825396825396826
# 3 variably 0.011904761904761904
#
# memorizing_speed
# ordinal 4
# 0 slowly 0.17063492063492064
# 1 moderately 0.5317460317460317
# 2 quickly 0.29365079365079366
# 3 variably 0.003968253968253968
#
# memory_auditory
# ordinal 2
# 0 poor 0.20553359683794467
# 1 good 0.7944664031620553
#
# memory_gustatory
# ordinal 2
# 0 poor 0.15019762845849802
# 1 good 0.849802371541502
#
# memory_olfactory
# ordinal 2
# 0 poor 0.25296442687747034
# 1 good 0.7470355731225297
#
# memory_tactile
# ordinal 2
# 0 poor 0.47035573122529645
# 1 good 0.5296442687747036
#
# memory_visual
# ordinal 2
# 0 poor 0.19367588932806323
# 1 good 0.8063241106719368
#
# mental_power
# ordinal 3
# 0 grade1 0.2608695652173913
# 1 grade2 0.5849802371541502
# 2 grade3 0.1541501976284585
#
# nails_length
# ordinal 3
# 0 tooshort/toolong 0.06349206349206349
# 1 medium 0.8095238095238095
# 2 long 0.12698412698412698
#
# perspiration_amount
# ordinal 4
# 0 low 0.30039525691699603
# 1 medium 0.45849802371541504
# 2 high 0.24110671936758893
# 3 variable 0
#
# physical_power
# ordinal 3
# 0 grade1 0.18972332015810275
# 1 grade2 0.5889328063241107
# 2 grade3 0.22134387351778656
#
# planning_quality
# ordinal 3
# 0 poor 0.19444444444444445
# 1 medium 0.6031746031746031
# 2 good 0.20238095238095238
#
# recalling_speed
# ordinal 4
# 0 slowly 0.11904761904761904
# 1 moderately 0.5873015873015873
# 2 quickly 0.28174603174603174
# 3 variably 0.011904761904761904
#
# resistance_power
# ordinal 3
# 0 grade1 0.15019762845849802
# 1 grade2 0.5731225296442688
# 2 grade3 0.2766798418972332
#
# retaining_quality
# ordinal 3
# 0 poor 0.2222222222222222
# 1 medium 0.47619047619047616
# 2 good 0.30158730158730157
#
# retainingfriends_quality
# ordinal 3
# 0 poor 0.04819277108433735
# 1 medium 0.7871485943775101
# 2 good 0.1646586345381526
#
# shoulder_breadth
# ordinal 3
# 0 thin/narrow 0.26294820717131473
# 1 medium 0.44621513944223107
# 2 broad 0.2908366533864542
#
# shoulder_movements
# ordinal 3
# 0 less 0.9285714285714286
# 1 moderate 0.06349206349206349
# 2 high/excessive 0.007936507936507936
#
# skin_type
# ordinal 7
# 0 thick 0.3739495798319328
# 1 thin 0.6260504201680672
# 2 dry 0
# 3 oily 0
# 4 normal 0
# 5 seasonal/variable 0
# 6 hard 0
#
# sleep_amount
# ordinal 4
# 0 low 0.10276679841897234
# 1 medium 0.7114624505928854
# 2 high 0.17786561264822134
# 3 variable 0.007905138339920948
#
# speaking_amount
# ordinal 3
# 0 less 0.11462450592885376
# 1 moderate 0.6521739130434783
# 2 excessive 0.233201581027668
#
# speaking_speed
# ordinal 4
# 0 slow 0.11904761904761904
# 1 medium 0.7182539682539683
# 2 quick 0.15873015873015872
# 3 variable 0.003968253968253968
#
# stool_consistency
# ordinal 3
# 0 loose/soft/semisolid 0.06374501992031872
# 1 medium 0.8326693227091634
# 2 hard 0.10358565737051793
#
# teeth_color
# ordinal 3
# 0 milkywhite 0.4940239043824701
# 1 yellowish 0.4103585657370518
# 2 dull/blackish 0.09561752988047809
#
# teeth_size
# ordinal 4
# 0 toosmall 0.05138339920948617
# 1 medium 0.8063241106719368
# 2 large 0.1383399209486166
# 3 toolarge 0.003952569169960474
#
# tongue_movements
# ordinal 3
# 0 less 0.9090909090909091
# 1 moderate 0.08695652173913043
# 2 high/excessive 0.003952569169960474
#
# walking_amount
# ordinal 3
# 0 less 0.09090909090909091
# 1 moderate 0.7193675889328063
# 2 high/excessive 0.18972332015810275
#
# walking_speed
# ordinal 4
# 0 slow 0.11857707509881422
# 1 medium 0.5889328063241107
# 2 quick/fast/brisk 0.2845849802371542
# 3 variable 0.007905138339920948
#
# walking_steps
# ordinal 3
# 0 small 0.12350597609561753
# 1 medium 0.8007968127490039
# 2 large 0.07569721115537849
#
# working_speed
# ordinal 4
# 0 slow 0.07114624505928854
# 1 medium 0.6482213438735178
# 2 quick/fast/brisk 0.26877470355731226
# 3 variable 0.011857707509881422

# %%
def entropy(features):
    for feat in features.values():
        for cat in feat.categories.values():
            if(cat.prob):
                cat.entropy = (-1)*cat.prob*math.log(cat.prob)
            else:
                pass

    return features

# %%
import math
feat = entropy(feat)

# %%
for f in feat.keys():
    print(f)
    print(feat[f].feat_type,feat[f].num_cat)
    for cat in feat[f].categories.keys():
        print(feat[f].categories[cat].index,feat[f].categories[cat].name,feat[f].categories[cat].prob,feat[f].categories[cat].entropy)
    print()
# Out:
# achievingends_quality
# ordinal 3
# 0 poor 0.1984126984126984 0.3209139051752534
# 1 medium 0.45634920634920634 0.35800456469063463
# 2 good 0.34523809523809523 0.3671679535339089
#
# anger_quality
# ordinal 3
# 0 poor 0.192 0.3168499021352363
# 1 medium 0.572 0.31952851650853803
# 2 good 0.236 0.3407659398537404
#
# anger_speed
# ordinal 4
# 0 slowly 0.18326693227091634 0.3109694460620067
# 1 moderately 0.3187250996015936 0.364438662775427
# 2 quickly 0.47808764940239046 0.3528101337130221
# 3 variably 0.0199203187250996 0.07800826746409728
#
# appetite_amount
# ordinal 4
# 0 low 0.17391304347826086 0.30420867040161026
# 1 medium 0.6521739130434783 0.2787678357566998
# 2 high 0.11462450592885376 0.24828741542881558
# 3 variable 0.05928853754940711 0.16751023444418836
#
# bladder_amount
# ordinal 4
# 0 low 0.012195121951219513 0.053740478625173824
# 1 medium 0.8780487804878049 0.11419299065695415
# 2 high 0.07317073170731707 0.19133852034411206
# 3 variable 0.036585365853658534 0.12102830336327353
#
# body_odour
# ordinal 3
# 0 veryless 0.44621513944223107 0.36007512190322394
# 1 mild 0.44621513944223107 0.36007512190322394
# 2 strong 0.10756972111553785 0.23983917918104095
#
# bodybuild_size
# ordinal 3
# 0 weaklydeveloped 0.2964426877470356 0.36044507169699896
# 1 moderatelydeveloped 0.44664031620553357 0.359992840757768
# 2 welldeveloped 0.25691699604743085 0.34915076768408065
#
# bodyframe_breadth
# ordinal 3
# 0 thin/narrow 0.3531746031746032 0.3675815550887152
# 1 medium 0.39285714285714285 0.3670500575408988
# 2 broad 0.25396825396825395 0.34807517565758767
#
# bodyframe_length
# ordinal 3
# 0 tooshort/toolong 0.08 0.20205829154466046
# 1 medium 0.712 0.24185028570995484
# 2 long 0.208 0.32660517745041034
#
# bodyhair_color
# ordinal 6
# 0 black 0.24206349206349206 0.3433804310461303
# 1 darkbrown 0.3412698412698413 0.36689299225468547
# 2 lightbrown 0.36904761904761907 0.3678775883940856
# 3 dusky 0.047619047619047616 0.14497725893921062
# 4 blonde 0 0
# 5 copper 0 0
#
# bodytemp_amount
# ordinal 4
# 0 low 0.2608695652173913 0.350539499139416
# 1 medium 0.4901185770750988 0.3495074405817705
# 2 high 0.23715415019762845 0.34127547664160146
# 3 variable 0.011857707509881422 0.05258629090979538
#
# bowel_tendency
# ordinal 3
# 0 constipation 0.26693227091633465 0.35255355148460077
# 1 none 0.5577689243027888 0.32563136379739904
# 2 loosemotion 0.1752988047808765 0.3052413762127291
#
# chest_breadth
# ordinal 3
# 0 thin/narrow 0.2619047619047619 0.35089328096035655
# 1 medium 0.5238095238095238 0.33870946734169416
# 2 broad 0.21428571428571427 0.3300953659172462
#
# digestive_amount
# ordinal 4
# 0 low 0.16600790513833993 0.29810369390772484
# 1 medium 0.616600790513834 0.29814712691923073
# 2 high 0.17391304347826086 0.30420867040161026
# 3 variable 0.043478260869565216 0.13632583547518043
#
# dreams_amount
# ordinal 4
# 0 low 0.3466135458167331 0.3672525871773562
# 1 medium 0.4820717131474104 0.351749600070678
# 2 high 0.06772908366533864 0.18234292078201056
# 3 variable 0.10358565737051793 0.23486560330226236
#
# execution_quality
# ordinal 3
# 0 poor 0.22310756972111553 0.33468394386538464
# 1 medium 0.6175298804780877 0.297666583438021
# 2 good 0.1593625498007968 0.2926810334689797
#
# eye_size
# ordinal 3
# 0 weaklydeveloped 0.233201581027668 0.33950699859480726
# 1 moderatelydeveloped 0.6877470355731226 0.25744722915122714
# 2 welldeveloped 0.07905138339920949 0.2006053134524529
#
# eyebrow_size
# ordinal 3
# 0 small 0.031746031746031744 0.10952341415338372
# 1 medium 0.8134920634920635 0.16792030641455596
# 2 large 0.15476190476190477 0.2887651992614655
#
# eyebrows_movements
# ordinal 3
# 0 less 0.8300395256916996 0.1546213880715843
# 1 moderate 0.16205533596837945 0.2949111237270819
# 2 high/excessive 0.007905138339920948 0.03826278504480296
#
# eyelash_size
# ordinal 3
# 0 small 0.07905138339920949 0.2006053134524529
# 1 medium 0.8893280632411067 0.10430847615690723
# 2 large 0.03162055335968379 0.10921574536119158
#
# eyes_movements
# ordinal 3
# 0 less 0.6007905138339921 0.30610815461639945
# 1 moderate 0.3794466403162055 0.3676994645728445
# 2 high/excessive 0.019762845849802372 0.07754845012437589
#
# face_size
# ordinal 3
# 0 weaklydeveloped 0.15476190476190477 0.2887651992614655
# 1 moderatelydeveloped 0.6984126984126984 0.2506918106162531
# 2 welldeveloped 0.14682539682539683 0.2816861645638348
#
# faith_quality
# ordinal 3
# 0 poor 0.264 0.3515968304206567
# 1 medium 0.52 0.3400417630514653
# 2 good 0.216 0.331015004200362
#
# forehead_breadth
# ordinal 3
# 0 thin/narrow 0.043824701195219126 0.13706428019787867
# 1 medium 0.8884462151394422 0.10508645574016465
# 2 broad 0.06772908366533864 0.18234292078201056
#
# forehead_length
# ordinal 3
# 0 tooshort/toolong 0.10358565737051793 0.23486560330226236
# 1 medium 0.8127490039840638 0.16850964477555283
# 2 long 0.08366533864541832 0.207567890556078
#
# forgetfulness_speed
# ordinal 4
# 0 slowly 0.27380952380952384 0.3546716596074497
# 1 moderately 0.42857142857142855 0.3631276544516587
# 2 quickly 0.2857142857142857 0.3579322767129623
# 3 variably 0.011904761904761904 0.05274781903384897
#
# forgiveness_quality
# ordinal 3
# 0 poor 0.099601593625498 0.2297387564007553
# 1 medium 0.5139442231075697 0.34210210751133235
# 2 good 0.38645418326693226 0.3674182078922506
#
# generosity_quality
# ordinal 3
# 0 poor 0.09090909090909091 0.21799047934530644
# 1 medium 0.5652173913043478 0.3224818765251726
# 2 good 0.3438735177865613 0.3670785738985987
#
# hair_growth
# ordinal 4
# 0 dense 0.1721311475409836 0.3028645143213648
# 1 scanty 0.0860655737704918 0.21108836696297276
# 2 moderate 0.7418032786885246 0.2215552709793241
# 3 bald 0 0
#
# hair_look
# ordinal 3
# 0 straight 0.7666666666666667 0.20370576039530433
# 1 wavy 0.1 0.23025850929940456
# 2 fizzy/curly 0.13333333333333333 0.268653736072302
#
# hair_type
# ordinal 9
# 0 thick 0.19444444444444445 0.3184239312723771
# 1 thin 0.8055555555555556 0.17417972626720674
# 2 coarse 0 0
# 3 hard 0 0
# 4 smooth 0 0
# 5 soft 0 0
# 6 straight 0 0
# 7 wavy 0 0
# 8 fizzy/curly 0 0
#
# hands_length
# ordinal 3
# 0 tooshort/toolong 0.02766798418972332 0.09925832165100967
# 1 medium 0.8695652173913043 0.12153212380448586
# 2 long 0.10276679841897234 0.2338245720093162
#
# hands_movements
# ordinal 3
# 0 less 0.32806324110671936 0.3656425182500654
# 1 moderate 0.5770750988142292 0.31726600231146573
# 2 high/excessive 0.09486166007905138 0.2234310505972719
#
# head_movements
# ordinal 3
# 0 less 0.746031746031746 0.218577696190941
# 1 moderate 0.20634920634920634 0.32565729835063406
# 2 high/excessive 0.047619047619047616 0.14497725893921062
#
# healing_power
# ordinal 3
# 0 grade1 0.08300395256916997 0.20658580265251403
# 1 grade2 0.7272727272727273 0.23160271354075243
# 2 grade3 0.18972332015810275 0.315355916740483
#
# healthproblem_in_temp
# ordinal 4
# 0 none 0.20242914979757085 0.323353305910897
# 1 cold 0.3967611336032389 0.3667742675296588
# 2 warm 0.340080971659919 0.36680165657454145
# 3 both 0.06072874493927125 0.170121749120998
#
# initiation_speed
# ordinal 4
# 0 slowly 0.08366533864541832 0.207567890556078
# 1 moderately 0.5338645418326693 0.33506040099695983
# 2 quickly 0.38247011952191234 0.36759384771210746
# 3 variably 0 0
#
# irritability_speed
# ordinal 4
# 0 slowly 0.2350597609561753 0.3403466701925809
# 1 moderately 0.3386454183266932 0.36668582878296707
# 2 quickly 0.41832669322709165 0.36456861291751935
# 3 variably 0.00796812749003984 0.038504428355154094
#
# jaw_movements
# ordinal 3
# 0 less 0.9523809523809523 0.046466823018506714
# 1 moderate 0.04365079365079365 0.13669393635652213
# 2 high/excessive 0.003968253968253968 0.021942178918696122
#
# joint_size
# ordinal 3
# 0 weaklydeveloped 0.2 0.3218875824868201
# 1 moderatelydeveloped 0.624 0.29428146422233065
# 2 welldeveloped 0.176 0.3057597459741414
#
# leg_length
# ordinal 3
# 0 tooshort/toolong 0.011857707509881422 0.05258629090979538
# 1 medium 0.8853754940711462 0.10778865557089173
# 2 long 0.10276679841897234 0.2338245720093162
#
# legs_movements
# ordinal 3
# 0 less 0.444 0.3604972381481611
# 1 moderate 0.512 0.3427484948186262
# 2 high/excessive 0.044 0.13743688838281054
#
# lip_size
# ordinal 3
# 0 small 0.12301587301587301 0.25777261259450235
# 1 medium 0.8055555555555556 0.17417972626720674
# 2 large 0.07142857142857142 0.18850409497251847
#
# lips_movements
# ordinal 3
# 0 less 0.766798418972332 0.20360900377412358
# 1 moderate 0.22529644268774704 0.3357678995687719
# 2 high/excessive 0.007905138339920948 0.03826278504480296
#
# makingfriends_speed
# ordinal 4
# 0 slowly 0.12301587301587301 0.25777261259450235
# 1 moderately 0.6468253968253969 0.2818081687811894
# 2 quickly 0.21825396825396826 0.3322034707354857
# 3 variably 0.011904761904761904 0.05274781903384897
#
# memorizing_speed
# ordinal 4
# 0 slowly 0.17063492063492064 0.301721610270508
# 1 moderately 0.5317460317460317 0.3358450973536055
# 2 quickly 0.29365079365079366 0.35982910943943164
# 3 variably 0.003968253968253968 0.021942178918696122
#
# memory_auditory
# ordinal 2
# 0 poor 0.20553359683794467 0.32518411086006654
# 1 good 0.7944664031620553 0.1827944692267089
#
# memory_gustatory
# ordinal 2
# 0 poor 0.15019762845849802 0.2847451640396961
# 1 good 0.849802371541502 0.13830657718960218
#
# memory_olfactory
# ordinal 2
# 0 poor 0.25296442687747034 0.3477012250732897
# 1 good 0.7470355731225297 0.21786730246335537
#
# memory_tactile
# ordinal 2
# 0 poor 0.47035573122529645 0.35477333390633564
# 1 good 0.5296442687747036 0.3366152501820774
#
# memory_visual
# ordinal 2
# 0 poor 0.19367588932806323 0.31793237288627585
# 1 good 0.8063241106719368 0.173576984016577
#
# mental_power
# ordinal 3
# 0 grade1 0.2608695652173913 0.350539499139416
# 1 grade2 0.5849802371541502 0.31365307436594453
# 2 grade3 0.1541501976284585 0.2882343314676564
#
# nails_length
# ordinal 3
# 0 tooshort/toolong 0.06349206349206349 0.17503748350931062
# 1 medium 0.8095238095238095 0.17105974249250083
# 2 long 0.12698412698412698 0.2620562774237075
#
# perspiration_amount
# ordinal 4
# 0 low 0.30039525691699603 0.36127220269379595
# 1 medium 0.45849802371541504 0.3575364368539686
# 2 high 0.24110671936758893 0.34297807548540216
# 3 variable 0 0
#
# physical_power
# ordinal 3
# 0 grade1 0.18972332015810275 0.315355916740483
# 1 grade2 0.5889328063241107 0.3118064594250083
# 2 grade3 0.22134387351778656 0.3337949276188647
#
# planning_quality
# ordinal 3
# 0 poor 0.19444444444444445 0.3184239312723771
# 1 medium 0.6031746031746031 0.30493405608373947
# 2 good 0.20238095238095238 0.3233245087069126
#
# recalling_speed
# ordinal 4
# 0 slowly 0.11904761904761904 0.2533609173630081
# 1 moderately 0.5873015873015873 0.3125717795023874
# 2 quickly 0.28174603174603174 0.35690156326737166
# 3 variably 0.011904761904761904 0.05274781903384897
#
# resistance_power
# ordinal 3
# 0 grade1 0.15019762845849802 0.2847451640396961
# 1 grade2 0.5731225296442688 0.3190319494644551
# 2 grade3 0.2766798418972332 0.3555043370255782
#
# retaining_quality
# ordinal 3
# 0 poor 0.2222222222222222 0.3342394215058387
# 1 medium 0.47619047619047616 0.35330349749017964
# 2 good 0.30158730158730157 0.36151141582978974
#
# retainingfriends_quality
# ordinal 3
# 0 poor 0.04819277108433735 0.146146807068757
# 1 medium 0.7871485943775101 0.188394757019684
# 2 good 0.1646586345381526 0.29702455429789715
#
# shoulder_breadth
# ordinal 3
# 0 thin/narrow 0.26294820717131473 0.35124574107152845
# 1 medium 0.44621513944223107 0.36007512190322394
# 2 broad 0.2908366533864542 0.35918137590752064
#
# shoulder_movements
# ordinal 3
# 0 less 0.9285714285714286 0.06881454557131315
# 1 moderate 0.06349206349206349 0.17503748350931062
# 2 high/excessive 0.007936507936507936 0.03838318973771014
#
# skin_type
# ordinal 7
# 0 thick 0.3739495798319328 0.3678296346663899
# 1 thin 0.6260504201680672 0.29319466718981646
# 2 dry 0 0
# 3 oily 0 0
# 4 normal 0 0
# 5 seasonal/variable 0 0
# 6 hard 0 0
#
# sleep_amount
# ordinal 4
# 0 low 0.10276679841897234 0.2338245720093162
# 1 medium 0.7114624505928854 0.24220503877753272
# 2 high 0.17786561264822134 0.3071253555457471
# 3 variable 0.007905138339920948 0.03826278504480296
#
# speaking_amount
# ordinal 3
# 0 less 0.11462450592885376 0.24828741542881558
# 1 moderate 0.6521739130434783 0.2787678357566998
# 2 excessive 0.233201581027668 0.33950699859480726
#
# speaking_speed
# ordinal 4
# 0 slow 0.11904761904761904 0.2533609173630081
# 1 medium 0.7182539682539683 0.23769326262084586
# 2 quick 0.15873015873015872 0.2921507354599186
# 3 variable 0.003968253968253968 0.021942178918696122
#
# stool_consistency
# ordinal 3
# 0 loose/soft/semisolid 0.06374501992031872 0.17548138434371333
# 1 medium 0.8326693227091634 0.15247731321871444
# 2 hard 0.10358565737051793 0.23486560330226236
#
# teeth_color
# ordinal 3
# 0 milkywhite 0.4940239043824701 0.3483715152084328
# 1 yellowish 0.4103585657370518 0.36551620295984566
# 2 dull/blackish 0.09561752988047809 0.22445250442554626
#
# teeth_size
# ordinal 4
# 0 toosmall 0.05138339920948617 0.15252854429429955
# 1 medium 0.8063241106719368 0.173576984016577
# 2 large 0.1383399209486166 0.27364209467720846
# 3 toolarge 0.003952569169960474 0.02187110469852775
#
# tongue_movements
# ordinal 3
# 0 less 0.9090909090909091 0.08664561800393172
# 1 moderate 0.08695652173913043 0.21237800307558297
# 2 high/excessive 0.003952569169960474 0.02187110469852775
#
# walking_amount
# ordinal 3
# 0 less 0.09090909090909091 0.21799047934530644
# 1 moderate 0.7193675889328063 0.23694731185941476
# 2 high/excessive 0.18972332015810275 0.315355916740483
#
# walking_speed
# ordinal 4
# 0 slow 0.11857707509881422 0.2528291036045887
# 1 medium 0.5889328063241107 0.3118064594250083
# 2 quick/fast/brisk 0.2845849802371542 0.357644595332907
# 3 variable 0.007905138339920948 0.03826278504480296
#
# walking_steps
# ordinal 3
# 0 small 0.12350597609561753 0.2583085170280708
# 1 medium 0.8007968127490039 0.1778954352414914
# 2 large 0.07569721115537849 0.1953755587224762
#
# working_speed
# ordinal 4
# 0 slow 0.07114624505928854 0.18804078717377234
# 1 medium 0.6482213438735178 0.28101890113891215
# 2 quick/fast/brisk 0.26877470355731226 0.3531381868833839
# 3 variable 0.011857707509881422 0.05258629090979538

# %%
def probability(df, features):
    for feat in features.keys():
        series = df[feat].value_counts(normalize=True,sort=False)
        for cat in series.index:
            features[feat].categories[cat].prob = series[cat]

    return features

def entropy(features):
    for feat in features.values():
        for cat in feat.categories.values():
            if(cat.prob):
                cat.entropy = (-1)*cat.prob*math.log(cat.prob)
            else:
                pass

    return features


def std_entropy(features):
    for feat in features.values():
        if(feat.num_cat):
            feat.std_entropy = math.log(feat.num_cat)
        else:
            pass

    return features

def feature_entropy(features):
    for feat in features.values():
        feat_entropy = 0
        for cat in feat.categories.values():
            feat_entropy = feat_entropy + cat.entropy

        feat.entropy = feat_entropy

    return features

def reliability(features):
    for feat in features.values():
        try:
            feat.reliability = feat.entropy/ feat.std_entropy
        except ZeroDivisionError as error:
            Logging.log_exception(error)

    return features

# %%
feat = std_entropy(feat)

# %%
feat = feature_entropy(feat)

# %%
feat = reliability(feat)

# %%
for f in feat.keys():
    print('name:',f)
    print('type:',feat[f].feat_type)
    print('num_cat:',feat[f].num_cat)
    print('entropy:',feat[f].entropy)
    print('std_entropy:',feat[f].std_entropy)
    print('reliability:',feat[f].reliability)
    print()
    for cat in feat[f].categories.keys():
        print('    index:',feat[f].categories[cat].index)
        print('    name:',feat[f].categories[cat].name)
        print('    prob:',feat[f].categories[cat].prob)
        print('    entropy:',feat[f].categories[cat].entropy)
        print()
    print()
# Out:
# name: achievingends_quality
# type: ordinal
# num_cat: 3
# entropy: 1.046086423399797
# std_entropy: 1.0986122886681098
# reliability: 0.9521888970202655
#
#     index: 0
#     name: poor
#     prob: 0.1984126984126984
#     entropy: 0.3209139051752534
#
#     index: 1
#     name: medium
#     prob: 0.45634920634920634
#     entropy: 0.35800456469063463
#
#     index: 2
#     name: good
#     prob: 0.34523809523809523
#     entropy: 0.3671679535339089
#
#
# name: anger_quality
# type: ordinal
# num_cat: 3
# entropy: 0.9771443584975147
# std_entropy: 1.0986122886681098
# reliability: 0.8894351251815549
#
#     index: 0
#     name: poor
#     prob: 0.192
#     entropy: 0.3168499021352363
#
#     index: 1
#     name: medium
#     prob: 0.572
#     entropy: 0.31952851650853803
#
#     index: 2
#     name: good
#     prob: 0.236
#     entropy: 0.3407659398537404
#
#
# name: anger_speed
# type: ordinal
# num_cat: 4
# entropy: 1.1062265100145532
# std_entropy: 1.3862943611198906
# reliability: 0.7979737500489505
#
#     index: 0
#     name: slowly
#     prob: 0.18326693227091634
#     entropy: 0.3109694460620067
#
#     index: 1
#     name: moderately
#     prob: 0.3187250996015936
#     entropy: 0.364438662775427
#
#     index: 2
#     name: quickly
#     prob: 0.47808764940239046
#     entropy: 0.3528101337130221
#
#     index: 3
#     name: variably
#     prob: 0.0199203187250996
#     entropy: 0.07800826746409728
#
#
# name: appetite_amount
# type: ordinal
# num_cat: 4
# entropy: 0.998774156031314
# std_entropy: 1.3862943611198906
# reliability: 0.7204632609372182
#
#     index: 0
#     name: low
#     prob: 0.17391304347826086
#     entropy: 0.30420867040161026
#
#     index: 1
#     name: medium
#     prob: 0.6521739130434783
#     entropy: 0.2787678357566998
#
#     index: 2
#     name: high
#     prob: 0.11462450592885376
#     entropy: 0.24828741542881558
#
#     index: 3
#     name: variable
#     prob: 0.05928853754940711
#     entropy: 0.16751023444418836
#
#
# name: bladder_amount
# type: ordinal
# num_cat: 4
# entropy: 0.4803002929895136
# std_entropy: 1.3862943611198906
# reliability: 0.34646342541674374
#
#     index: 0
#     name: low
#     prob: 0.012195121951219513
#     entropy: 0.053740478625173824
#
#     index: 1
#     name: medium
#     prob: 0.8780487804878049
#     entropy: 0.11419299065695415
#
#     index: 2
#     name: high
#     prob: 0.07317073170731707
#     entropy: 0.19133852034411206
#
#     index: 3
#     name: variable
#     prob: 0.036585365853658534
#     entropy: 0.12102830336327353
#
#
# name: body_odour
# type: ordinal
# num_cat: 3
# entropy: 0.9599894229874888
# std_entropy: 1.0986122886681098
# reliability: 0.8738200299500756
#
#     index: 0
#     name: veryless
#     prob: 0.44621513944223107
#     entropy: 0.36007512190322394
#
#     index: 1
#     name: mild
#     prob: 0.44621513944223107
#     entropy: 0.36007512190322394
#
#     index: 2
#     name: strong
#     prob: 0.10756972111553785
#     entropy: 0.23983917918104095
#
#
# name: bodybuild_size
# type: ordinal
# num_cat: 3
# entropy: 1.0695886801388477
# std_entropy: 1.0986122886681098
# reliability: 0.9735815730184044
#
#     index: 0
#     name: weaklydeveloped
#     prob: 0.2964426877470356
#     entropy: 0.36044507169699896
#
#     index: 1
#     name: moderatelydeveloped
#     prob: 0.44664031620553357
#     entropy: 0.359992840757768
#
#     index: 2
#     name: welldeveloped
#     prob: 0.25691699604743085
#     entropy: 0.34915076768408065
#
#
# name: bodyframe_breadth
# type: ordinal
# num_cat: 3
# entropy: 1.0827067882872017
# std_entropy: 1.0986122886681098
# reliability: 0.9855221896341694
#
#     index: 0
#     name: thin/narrow
#     prob: 0.3531746031746032
#     entropy: 0.3675815550887152
#
#     index: 1
#     name: medium
#     prob: 0.39285714285714285
#     entropy: 0.3670500575408988
#
#     index: 2
#     name: broad
#     prob: 0.25396825396825395
#     entropy: 0.34807517565758767
#
#
# name: bodyframe_length
# type: ordinal
# num_cat: 3
# entropy: 0.7705137547050256
# std_entropy: 1.0986122886681098
# reliability: 0.7013518441880431
#
#     index: 0
#     name: tooshort/toolong
#     prob: 0.08
#     entropy: 0.20205829154466046
#
#     index: 1
#     name: medium
#     prob: 0.712
#     entropy: 0.24185028570995484
#
#     index: 2
#     name: long
#     prob: 0.208
#     entropy: 0.32660517745041034
#
#
# name: bodyhair_color
# type: ordinal
# num_cat: 6
# entropy: 1.223128270634112
# std_entropy: 1.791759469228055
# reliability: 0.6826408854761478
#
#     index: 0
#     name: black
#     prob: 0.24206349206349206
#     entropy: 0.3433804310461303
#
#     index: 1
#     name: darkbrown
#     prob: 0.3412698412698413
#     entropy: 0.36689299225468547
#
#     index: 2
#     name: lightbrown
#     prob: 0.36904761904761907
#     entropy: 0.3678775883940856
#
#     index: 3
#     name: dusky
#     prob: 0.047619047619047616
#     entropy: 0.14497725893921062
#
#     index: 4
#     name: blonde
#     prob: 0
#     entropy: 0
#
#     index: 5
#     name: copper
#     prob: 0
#     entropy: 0
#
#
# name: bodytemp_amount
# type: ordinal
# num_cat: 4
# entropy: 1.0939087072725835
# std_entropy: 1.3862943611198906
# reliability: 0.7890883335837064
#
#     index: 0
#     name: low
#     prob: 0.2608695652173913
#     entropy: 0.350539499139416
#
#     index: 1
#     name: medium
#     prob: 0.4901185770750988
#     entropy: 0.3495074405817705
#
#     index: 2
#     name: high
#     prob: 0.23715415019762845
#     entropy: 0.34127547664160146
#
#     index: 3
#     name: variable
#     prob: 0.011857707509881422
#     entropy: 0.05258629090979538
#
#
# name: bowel_tendency
# type: ordinal
# num_cat: 3
# entropy: 0.9834262914947289
# std_entropy: 1.0986122886681098
# reliability: 0.8951531870146607
#
#     index: 0
#     name: constipation
#     prob: 0.26693227091633465
#     entropy: 0.35255355148460077
#
#     index: 1
#     name: none
#     prob: 0.5577689243027888
#     entropy: 0.32563136379739904
#
#     index: 2
#     name: loosemotion
#     prob: 0.1752988047808765
#     entropy: 0.3052413762127291
#
#
# name: chest_breadth
# type: ordinal
# num_cat: 3
# entropy: 1.019698114219297
# std_entropy: 1.0986122886681098
# reliability: 0.9281692228798173
#
#     index: 0
#     name: thin/narrow
#     prob: 0.2619047619047619
#     entropy: 0.35089328096035655
#
#     index: 1
#     name: medium
#     prob: 0.5238095238095238
#     entropy: 0.33870946734169416
#
#     index: 2
#     name: broad
#     prob: 0.21428571428571427
#     entropy: 0.3300953659172462
#
#
# name: digestive_amount
# type: ordinal
# num_cat: 4
# entropy: 1.0367853267037463
# std_entropy: 1.3862943611198906
# reliability: 0.7478825246509694
#
#     index: 0
#     name: low
#     prob: 0.16600790513833993
#     entropy: 0.29810369390772484
#
#     index: 1
#     name: medium
#     prob: 0.616600790513834
#     entropy: 0.29814712691923073
#
#     index: 2
#     name: high
#     prob: 0.17391304347826086
#     entropy: 0.30420867040161026
#
#     index: 3
#     name: variable
#     prob: 0.043478260869565216
#     entropy: 0.13632583547518043
#
#
# name: dreams_amount
# type: ordinal
# num_cat: 4
# entropy: 1.136210711332307
# std_entropy: 1.3862943611198906
# reliability: 0.8196027793220204
#
#     index: 0
#     name: low
#     prob: 0.3466135458167331
#     entropy: 0.3672525871773562
#
#     index: 1
#     name: medium
#     prob: 0.4820717131474104
#     entropy: 0.351749600070678
#
#     index: 2
#     name: high
#     prob: 0.06772908366533864
#     entropy: 0.18234292078201056
#
#     index: 3
#     name: variable
#     prob: 0.10358565737051793
#     entropy: 0.23486560330226236
#
#
# name: execution_quality
# type: ordinal
# num_cat: 3
# entropy: 0.9250315607723854
# std_entropy: 1.0986122886681098
# reliability: 0.8420000124828723
#
#     index: 0
#     name: poor
#     prob: 0.22310756972111553
#     entropy: 0.33468394386538464
#
#     index: 1
#     name: medium
#     prob: 0.6175298804780877
#     entropy: 0.297666583438021
#
#     index: 2
#     name: good
#     prob: 0.1593625498007968
#     entropy: 0.2926810334689797
#
#
# name: eye_size
# type: ordinal
# num_cat: 3
# entropy: 0.7975595411984874
# std_entropy: 1.0986122886681098
# reliability: 0.7259699799693663
#
#     index: 0
#     name: weaklydeveloped
#     prob: 0.233201581027668
#     entropy: 0.33950699859480726
#
#     index: 1
#     name: moderatelydeveloped
#     prob: 0.6877470355731226
#     entropy: 0.25744722915122714
#
#     index: 2
#     name: welldeveloped
#     prob: 0.07905138339920949
#     entropy: 0.2006053134524529
#
#
# name: eyebrow_size
# type: ordinal
# num_cat: 3
# entropy: 0.5662089198294051
# std_entropy: 1.0986122886681098
# reliability: 0.5153855692947347
#
#     index: 0
#     name: small
#     prob: 0.031746031746031744
#     entropy: 0.10952341415338372
#
#     index: 1
#     name: medium
#     prob: 0.8134920634920635
#     entropy: 0.16792030641455596
#
#     index: 2
#     name: large
#     prob: 0.15476190476190477
#     entropy: 0.2887651992614655
#
#
# name: eyebrows_movements
# type: ordinal
# num_cat: 3
# entropy: 0.4877952968434691
# std_entropy: 1.0986122886681098
# reliability: 0.44401041375100786
#
#     index: 0
#     name: less
#     prob: 0.8300395256916996
#     entropy: 0.1546213880715843
#
#     index: 1
#     name: moderate
#     prob: 0.16205533596837945
#     entropy: 0.2949111237270819
#
#     index: 2
#     name: high/excessive
#     prob: 0.007905138339920948
#     entropy: 0.03826278504480296
#
#
# name: eyelash_size
# type: ordinal
# num_cat: 3
# entropy: 0.4141295349705517
# std_entropy: 1.0986122886681098
# reliability: 0.37695694763492676
#
#     index: 0
#     name: small
#     prob: 0.07905138339920949
#     entropy: 0.2006053134524529
#
#     index: 1
#     name: medium
#     prob: 0.8893280632411067
#     entropy: 0.10430847615690723
#
#     index: 2
#     name: large
#     prob: 0.03162055335968379
#     entropy: 0.10921574536119158
#
#
# name: eyes_movements
# type: ordinal
# num_cat: 3
# entropy: 0.7513560693136199
# std_entropy: 1.0986122886681098
# reliability: 0.6839137674534097
#
#     index: 0
#     name: less
#     prob: 0.6007905138339921
#     entropy: 0.30610815461639945
#
#     index: 1
#     name: moderate
#     prob: 0.3794466403162055
#     entropy: 0.3676994645728445
#
#     index: 2
#     name: high/excessive
#     prob: 0.019762845849802372
#     entropy: 0.07754845012437589
#
#
# name: face_size
# type: ordinal
# num_cat: 3
# entropy: 0.8211431744415534
# std_entropy: 1.0986122886681098
# reliability: 0.7474367280535857
#
#     index: 0
#     name: weaklydeveloped
#     prob: 0.15476190476190477
#     entropy: 0.2887651992614655
#
#     index: 1
#     name: moderatelydeveloped
#     prob: 0.6984126984126984
#     entropy: 0.2506918106162531
#
#     index: 2
#     name: welldeveloped
#     prob: 0.14682539682539683
#     entropy: 0.2816861645638348
#
#
# name: faith_quality
# type: ordinal
# num_cat: 3
# entropy: 1.022653597672484
# std_entropy: 1.0986122886681098
# reliability: 0.9308594198525547
#
#     index: 0
#     name: poor
#     prob: 0.264
#     entropy: 0.3515968304206567
#
#     index: 1
#     name: medium
#     prob: 0.52
#     entropy: 0.3400417630514653
#
#     index: 2
#     name: good
#     prob: 0.216
#     entropy: 0.331015004200362
#
#
# name: forehead_breadth
# type: ordinal
# num_cat: 3
# entropy: 0.4244936567200539
# std_entropy: 1.0986122886681098
# reliability: 0.38639077780086
#
#     index: 0
#     name: thin/narrow
#     prob: 0.043824701195219126
#     entropy: 0.13706428019787867
#
#     index: 1
#     name: medium
#     prob: 0.8884462151394422
#     entropy: 0.10508645574016465
#
#     index: 2
#     name: broad
#     prob: 0.06772908366533864
#     entropy: 0.18234292078201056
#
#
# name: forehead_length
# type: ordinal
# num_cat: 3
# entropy: 0.6109431386338933
# std_entropy: 1.0986122886681098
# reliability: 0.5561044100230876
#
#     index: 0
#     name: tooshort/toolong
#     prob: 0.10358565737051793
#     entropy: 0.23486560330226236
#
#     index: 1
#     name: medium
#     prob: 0.8127490039840638
#     entropy: 0.16850964477555283
#
#     index: 2
#     name: long
#     prob: 0.08366533864541832
#     entropy: 0.207567890556078
#
#
# name: forgetfulness_speed
# type: ordinal
# num_cat: 4
# entropy: 1.1284794098059197
# std_entropy: 1.3862943611198906
# reliability: 0.8140258241361523
#
#     index: 0
#     name: slowly
#     prob: 0.27380952380952384
#     entropy: 0.3546716596074497
#
#     index: 1
#     name: moderately
#     prob: 0.42857142857142855
#     entropy: 0.3631276544516587
#
#     index: 2
#     name: quickly
#     prob: 0.2857142857142857
#     entropy: 0.3579322767129623
#
#     index: 3
#     name: variably
#     prob: 0.011904761904761904
#     entropy: 0.05274781903384897
#
#
# name: forgiveness_quality
# type: ordinal
# num_cat: 3
# entropy: 0.9392590718043383
# std_entropy: 1.0986122886681098
# reliability: 0.854950451121422
#
#     index: 0
#     name: poor
#     prob: 0.099601593625498
#     entropy: 0.2297387564007553
#
#     index: 1
#     name: medium
#     prob: 0.5139442231075697
#     entropy: 0.34210210751133235
#
#     index: 2
#     name: good
#     prob: 0.38645418326693226
#     entropy: 0.3674182078922506
#
#
# name: generosity_quality
# type: ordinal
# num_cat: 3
# entropy: 0.9075509297690778
# std_entropy: 1.0986122886681098
# reliability: 0.8260884564374725
#
#     index: 0
#     name: poor
#     prob: 0.09090909090909091
#     entropy: 0.21799047934530644
#
#     index: 1
#     name: medium
#     prob: 0.5652173913043478
#     entropy: 0.3224818765251726
#
#     index: 2
#     name: good
#     prob: 0.3438735177865613
#     entropy: 0.3670785738985987
#
#
# name: hair_growth
# type: ordinal
# num_cat: 4
# entropy: 0.7355081522636617
# std_entropy: 1.3862943611198906
# reliability: 0.5305569819020947
#
#     index: 0
#     name: dense
#     prob: 0.1721311475409836
#     entropy: 0.3028645143213648
#
#     index: 1
#     name: scanty
#     prob: 0.0860655737704918
#     entropy: 0.21108836696297276
#
#     index: 2
#     name: moderate
#     prob: 0.7418032786885246
#     entropy: 0.2215552709793241
#
#     index: 3
#     name: bald
#     prob: 0
#     entropy: 0
#
#
# name: hair_look
# type: ordinal
# num_cat: 3
# entropy: 0.7026180057670108
# std_entropy: 1.0986122886681098
# reliability: 0.6395504701834547
#
#     index: 0
#     name: straight
#     prob: 0.7666666666666667
#     entropy: 0.20370576039530433
#
#     index: 1
#     name: wavy
#     prob: 0.1
#     entropy: 0.23025850929940456
#
#     index: 2
#     name: fizzy/curly
#     prob: 0.13333333333333333
#     entropy: 0.268653736072302
#
#
# name: hair_type
# type: ordinal
# num_cat: 9
# entropy: 0.49260365753958385
# std_entropy: 2.1972245773362196
# reliability: 0.22419358613619111
#
#     index: 0
#     name: thick
#     prob: 0.19444444444444445
#     entropy: 0.3184239312723771
#
#     index: 1
#     name: thin
#     prob: 0.8055555555555556
#     entropy: 0.17417972626720674
#
#     index: 2
#     name: coarse
#     prob: 0
#     entropy: 0
#
#     index: 3
#     name: hard
#     prob: 0
#     entropy: 0
#
#     index: 4
#     name: smooth
#     prob: 0
#     entropy: 0
#
#     index: 5
#     name: soft
#     prob: 0
#     entropy: 0
#
#     index: 6
#     name: straight
#     prob: 0
#     entropy: 0
#
#     index: 7
#     name: wavy
#     prob: 0
#     entropy: 0
#
#     index: 8
#     name: fizzy/curly
#     prob: 0
#     entropy: 0
#
#
# name: hands_length
# type: ordinal
# num_cat: 3
# entropy: 0.4546150174648117
# std_entropy: 1.0986122886681098
# reliability: 0.41380842191011635
#
#     index: 0
#     name: tooshort/toolong
#     prob: 0.02766798418972332
#     entropy: 0.09925832165100967
#
#     index: 1
#     name: medium
#     prob: 0.8695652173913043
#     entropy: 0.12153212380448586
#
#     index: 2
#     name: long
#     prob: 0.10276679841897234
#     entropy: 0.2338245720093162
#
#
# name: hands_movements
# type: ordinal
# num_cat: 3
# entropy: 0.9063395711588029
# std_entropy: 1.0986122886681098
# reliability: 0.8249858303128882
#
#     index: 0
#     name: less
#     prob: 0.32806324110671936
#     entropy: 0.3656425182500654
#
#     index: 1
#     name: moderate
#     prob: 0.5770750988142292
#     entropy: 0.31726600231146573
#
#     index: 2
#     name: high/excessive
#     prob: 0.09486166007905138
#     entropy: 0.2234310505972719
#
#
# name: head_movements
# type: ordinal
# num_cat: 3
# entropy: 0.6892122534807857
# std_entropy: 1.0986122886681098
# reliability: 0.6273480285900902
#
#     index: 0
#     name: less
#     prob: 0.746031746031746
#     entropy: 0.218577696190941
#
#     index: 1
#     name: moderate
#     prob: 0.20634920634920634
#     entropy: 0.32565729835063406
#
#     index: 2
#     name: high/excessive
#     prob: 0.047619047619047616
#     entropy: 0.14497725893921062
#
#
# name: healing_power
# type: ordinal
# num_cat: 3
# entropy: 0.7535444329337495
# std_entropy: 1.0986122886681098
# reliability: 0.6859057018625748
#
#     index: 0
#     name: grade1
#     prob: 0.08300395256916997
#     entropy: 0.20658580265251403
#
#     index: 1
#     name: grade2
#     prob: 0.7272727272727273
#     entropy: 0.23160271354075243
#
#     index: 2
#     name: grade3
#     prob: 0.18972332015810275
#     entropy: 0.315355916740483
#
#
# name: healthproblem_in_temp
# type: ordinal
# num_cat: 4
# entropy: 1.2270509791360955
# std_entropy: 1.3862943611198906
# reliability: 0.885130181258796
#
#     index: 0
#     name: none
#     prob: 0.20242914979757085
#     entropy: 0.323353305910897
#
#     index: 1
#     name: cold
#     prob: 0.3967611336032389
#     entropy: 0.3667742675296588
#
#     index: 2
#     name: warm
#     prob: 0.340080971659919
#     entropy: 0.36680165657454145
#
#     index: 3
#     name: both
#     prob: 0.06072874493927125
#     entropy: 0.170121749120998
#
#
# name: initiation_speed
# type: ordinal
# num_cat: 4
# entropy: 0.9102221392651453
# std_entropy: 1.3862943611198906
# reliability: 0.6565864832125843
#
#     index: 0
#     name: slowly
#     prob: 0.08366533864541832
#     entropy: 0.207567890556078
#
#     index: 1
#     name: moderately
#     prob: 0.5338645418326693
#     entropy: 0.33506040099695983
#
#     index: 2
#     name: quickly
#     prob: 0.38247011952191234
#     entropy: 0.36759384771210746
#
#     index: 3
#     name: variably
#     prob: 0
#     entropy: 0
#
#
# name: irritability_speed
# type: ordinal
# num_cat: 4
# entropy: 1.1101055402482214
# std_entropy: 1.3862943611198906
# reliability: 0.8007718788897363
#
#     index: 0
#     name: slowly
#     prob: 0.2350597609561753
#     entropy: 0.3403466701925809
#
#     index: 1
#     name: moderately
#     prob: 0.3386454183266932
#     entropy: 0.36668582878296707
#
#     index: 2
#     name: quickly
#     prob: 0.41832669322709165
#     entropy: 0.36456861291751935
#
#     index: 3
#     name: variably
#     prob: 0.00796812749003984
#     entropy: 0.038504428355154094
#
#
# name: jaw_movements
# type: ordinal
# num_cat: 3
# entropy: 0.20510293829372497
# std_entropy: 1.0986122886681098
# reliability: 0.18669273993137214
#
#     index: 0
#     name: less
#     prob: 0.9523809523809523
#     entropy: 0.046466823018506714
#
#     index: 1
#     name: moderate
#     prob: 0.04365079365079365
#     entropy: 0.13669393635652213
#
#     index: 2
#     name: high/excessive
#     prob: 0.003968253968253968
#     entropy: 0.021942178918696122
#
#
# name: joint_size
# type: ordinal
# num_cat: 3
# entropy: 0.9219287926832922
# std_entropy: 1.0986122886681098
# reliability: 0.8391757512570537
#
#     index: 0
#     name: weaklydeveloped
#     prob: 0.2
#     entropy: 0.3218875824868201
#
#     index: 1
#     name: moderatelydeveloped
#     prob: 0.624
#     entropy: 0.29428146422233065
#
#     index: 2
#     name: welldeveloped
#     prob: 0.176
#     entropy: 0.3057597459741414
#
#
# name: leg_length
# type: ordinal
# num_cat: 3
# entropy: 0.39419951849000334
# std_entropy: 1.0986122886681098
# reliability: 0.3588158648470123
#
#     index: 0
#     name: tooshort/toolong
#     prob: 0.011857707509881422
#     entropy: 0.05258629090979538
#
#     index: 1
#     name: medium
#     prob: 0.8853754940711462
#     entropy: 0.10778865557089173
#
#     index: 2
#     name: long
#     prob: 0.10276679841897234
#     entropy: 0.2338245720093162
#
#
# name: legs_movements
# type: ordinal
# num_cat: 3
# entropy: 0.8406826213495978
# std_entropy: 1.0986122886681098
# reliability: 0.7652222990958802
#
#     index: 0
#     name: less
#     prob: 0.444
#     entropy: 0.3604972381481611
#
#     index: 1
#     name: moderate
#     prob: 0.512
#     entropy: 0.3427484948186262
#
#     index: 2
#     name: high/excessive
#     prob: 0.044
#     entropy: 0.13743688838281054
#
#
# name: lip_size
# type: ordinal
# num_cat: 3
# entropy: 0.6204564338342275
# std_entropy: 1.0986122886681098
# reliability: 0.5647637844889127
#
#     index: 0
#     name: small
#     prob: 0.12301587301587301
#     entropy: 0.25777261259450235
#
#     index: 1
#     name: medium
#     prob: 0.8055555555555556
#     entropy: 0.17417972626720674
#
#     index: 2
#     name: large
#     prob: 0.07142857142857142
#     entropy: 0.18850409497251847
#
#
# name: lips_movements
# type: ordinal
# num_cat: 3
# entropy: 0.5776396883876984
# std_entropy: 1.0986122886681098
# reliability: 0.5257903032269859
#
#     index: 0
#     name: less
#     prob: 0.766798418972332
#     entropy: 0.20360900377412358
#
#     index: 1
#     name: moderate
#     prob: 0.22529644268774704
#     entropy: 0.3357678995687719
#
#     index: 2
#     name: high/excessive
#     prob: 0.007905138339920948
#     entropy: 0.03826278504480296
#
#
# name: makingfriends_speed
# type: ordinal
# num_cat: 4
# entropy: 0.9245320711450263
# std_entropy: 1.3862943611198906
# reliability: 0.666908917091866
#
#     index: 0
#     name: slowly
#     prob: 0.12301587301587301
#     entropy: 0.25777261259450235
#
#     index: 1
#     name: moderately
#     prob: 0.6468253968253969
#     entropy: 0.2818081687811894
#
#     index: 2
#     name: quickly
#     prob: 0.21825396825396826
#     entropy: 0.3322034707354857
#
#     index: 3
#     name: variably
#     prob: 0.011904761904761904
#     entropy: 0.05274781903384897
#
#
# name: memorizing_speed
# type: ordinal
# num_cat: 4
# entropy: 1.0193379959822413
# std_entropy: 1.3862943611198906
# reliability: 0.7352969358966368
#
#     index: 0
#     name: slowly
#     prob: 0.17063492063492064
#     entropy: 0.301721610270508
#
#     index: 1
#     name: moderately
#     prob: 0.5317460317460317
#     entropy: 0.3358450973536055
#
#     index: 2
#     name: quickly
#     prob: 0.29365079365079366
#     entropy: 0.35982910943943164
#
#     index: 3
#     name: variably
#     prob: 0.003968253968253968
#     entropy: 0.021942178918696122
#
#
# name: memory_auditory
# type: ordinal
# num_cat: 2
# entropy: 0.5079785800867754
# std_entropy: 0.6931471805599453
# reliability: 0.7328581783690081
#
#     index: 0
#     name: poor
#     prob: 0.20553359683794467
#     entropy: 0.32518411086006654
#
#     index: 1
#     name: good
#     prob: 0.7944664031620553
#     entropy: 0.1827944692267089
#
#
# name: memory_gustatory
# type: ordinal
# num_cat: 2
# entropy: 0.42305174122929823
# std_entropy: 0.6931471805599453
# reliability: 0.6103346491109496
#
#     index: 0
#     name: poor
#     prob: 0.15019762845849802
#     entropy: 0.2847451640396961
#
#     index: 1
#     name: good
#     prob: 0.849802371541502
#     entropy: 0.13830657718960218
#
#
# name: memory_olfactory
# type: ordinal
# num_cat: 2
# entropy: 0.5655685275366451
# std_entropy: 0.6931471805599453
# reliability: 0.8159429099599911
#
#     index: 0
#     name: poor
#     prob: 0.25296442687747034
#     entropy: 0.3477012250732897
#
#     index: 1
#     name: good
#     prob: 0.7470355731225297
#     entropy: 0.21786730246335537
#
#
# name: memory_tactile
# type: ordinal
# num_cat: 2
# entropy: 0.6913885840884131
# std_entropy: 0.6931471805599453
# reliability: 0.9974628815915957
#
#     index: 0
#     name: poor
#     prob: 0.47035573122529645
#     entropy: 0.35477333390633564
#
#     index: 1
#     name: good
#     prob: 0.5296442687747036
#     entropy: 0.3366152501820774
#
#
# name: memory_visual
# type: ordinal
# num_cat: 2
# entropy: 0.49150935690285286
# std_entropy: 0.6931471805599453
# reliability: 0.7090981117542694
#
#     index: 0
#     name: poor
#     prob: 0.19367588932806323
#     entropy: 0.31793237288627585
#
#     index: 1
#     name: good
#     prob: 0.8063241106719368
#     entropy: 0.173576984016577
#
#
# name: mental_power
# type: ordinal
# num_cat: 3
# entropy: 0.952426904973017
# std_entropy: 1.0986122886681098
# reliability: 0.8669363294012312
#
#     index: 0
#     name: grade1
#     prob: 0.2608695652173913
#     entropy: 0.350539499139416
#
#     index: 1
#     name: grade2
#     prob: 0.5849802371541502
#     entropy: 0.31365307436594453
#
#     index: 2
#     name: grade3
#     prob: 0.1541501976284585
#     entropy: 0.2882343314676564
#
#
# name: nails_length
# type: ordinal
# num_cat: 3
# entropy: 0.608153503425519
# std_entropy: 1.0986122886681098
# reliability: 0.5535651746284461
#
#     index: 0
#     name: tooshort/toolong
#     prob: 0.06349206349206349
#     entropy: 0.17503748350931062
#
#     index: 1
#     name: medium
#     prob: 0.8095238095238095
#     entropy: 0.17105974249250083
#
#     index: 2
#     name: long
#     prob: 0.12698412698412698
#     entropy: 0.2620562774237075
#
#
# name: perspiration_amount
# type: ordinal
# num_cat: 4
# entropy: 1.0617867150331666
# std_entropy: 1.3862943611198906
# reliability: 0.7659172141300662
#
#     index: 0
#     name: low
#     prob: 0.30039525691699603
#     entropy: 0.36127220269379595
#
#     index: 1
#     name: medium
#     prob: 0.45849802371541504
#     entropy: 0.3575364368539686
#
#     index: 2
#     name: high
#     prob: 0.24110671936758893
#     entropy: 0.34297807548540216
#
#     index: 3
#     name: variable
#     prob: 0
#     entropy: 0
#
#
# name: physical_power
# type: ordinal
# num_cat: 3
# entropy: 0.960957303784356
# std_entropy: 1.0986122886681098
# reliability: 0.8747010330180829
#
#     index: 0
#     name: grade1
#     prob: 0.18972332015810275
#     entropy: 0.315355916740483
#
#     index: 1
#     name: grade2
#     prob: 0.5889328063241107
#     entropy: 0.3118064594250083
#
#     index: 2
#     name: grade3
#     prob: 0.22134387351778656
#     entropy: 0.3337949276188647
#
#
# name: planning_quality
# type: ordinal
# num_cat: 3
# entropy: 0.9466824960630291
# std_entropy: 1.0986122886681098
# reliability: 0.8617075430775756
#
#     index: 0
#     name: poor
#     prob: 0.19444444444444445
#     entropy: 0.3184239312723771
#
#     index: 1
#     name: medium
#     prob: 0.6031746031746031
#     entropy: 0.30493405608373947
#
#     index: 2
#     name: good
#     prob: 0.20238095238095238
#     entropy: 0.3233245087069126
#
#
# name: recalling_speed
# type: ordinal
# num_cat: 4
# entropy: 0.9755820791666161
# std_entropy: 1.3862943611198906
# reliability: 0.7037337137969106
#
#     index: 0
#     name: slowly
#     prob: 0.11904761904761904
#     entropy: 0.2533609173630081
#
#     index: 1
#     name: moderately
#     prob: 0.5873015873015873
#     entropy: 0.3125717795023874
#
#     index: 2
#     name: quickly
#     prob: 0.28174603174603174
#     entropy: 0.35690156326737166
#
#     index: 3
#     name: variably
#     prob: 0.011904761904761904
#     entropy: 0.05274781903384897
#
#
# name: resistance_power
# type: ordinal
# num_cat: 3
# entropy: 0.9592814505297294
# std_entropy: 1.0986122886681098
# reliability: 0.8731756056476515
#
#     index: 0
#     name: grade1
#     prob: 0.15019762845849802
#     entropy: 0.2847451640396961
#
#     index: 1
#     name: grade2
#     prob: 0.5731225296442688
#     entropy: 0.3190319494644551
#
#     index: 2
#     name: grade3
#     prob: 0.2766798418972332
#     entropy: 0.3555043370255782
#
#
# name: retaining_quality
# type: ordinal
# num_cat: 3
# entropy: 1.049054334825808
# std_entropy: 1.0986122886681098
# reliability: 0.9548904064213747
#
#     index: 0
#     name: poor
#     prob: 0.2222222222222222
#     entropy: 0.3342394215058387
#
#     index: 1
#     name: medium
#     prob: 0.47619047619047616
#     entropy: 0.35330349749017964
#
#     index: 2
#     name: good
#     prob: 0.30158730158730157
#     entropy: 0.36151141582978974
#
#
# name: retainingfriends_quality
# type: ordinal
# num_cat: 3
# entropy: 0.6315661183863381
# std_entropy: 1.0986122886681098
# reliability: 0.574876255163694
#
#     index: 0
#     name: poor
#     prob: 0.04819277108433735
#     entropy: 0.146146807068757
#
#     index: 1
#     name: medium
#     prob: 0.7871485943775101
#     entropy: 0.188394757019684
#
#     index: 2
#     name: good
#     prob: 0.1646586345381526
#     entropy: 0.29702455429789715
#
#
# name: shoulder_breadth
# type: ordinal
# num_cat: 3
# entropy: 1.070502238882273
# std_entropy: 1.0986122886681098
# reliability: 0.974413130022498
#
#     index: 0
#     name: thin/narrow
#     prob: 0.26294820717131473
#     entropy: 0.35124574107152845
#
#     index: 1
#     name: medium
#     prob: 0.44621513944223107
#     entropy: 0.36007512190322394
#
#     index: 2
#     name: broad
#     prob: 0.2908366533864542
#     entropy: 0.35918137590752064
#
#
# name: shoulder_movements
# type: ordinal
# num_cat: 3
# entropy: 0.2822352188183339
# std_entropy: 1.0986122886681098
# reliability: 0.25690156730405644
#
#     index: 0
#     name: less
#     prob: 0.9285714285714286
#     entropy: 0.06881454557131315
#
#     index: 1
#     name: moderate
#     prob: 0.06349206349206349
#     entropy: 0.17503748350931062
#
#     index: 2
#     name: high/excessive
#     prob: 0.007936507936507936
#     entropy: 0.03838318973771014
#
#
# name: skin_type
# type: ordinal
# num_cat: 7
# entropy: 0.6610243018562063
# std_entropy: 1.9459101490553132
# reliability: 0.33969929299002616
#
#     index: 0
#     name: thick
#     prob: 0.3739495798319328
#     entropy: 0.3678296346663899
#
#     index: 1
#     name: thin
#     prob: 0.6260504201680672
#     entropy: 0.29319466718981646
#
#     index: 2
#     name: dry
#     prob: 0
#     entropy: 0
#
#     index: 3
#     name: oily
#     prob: 0
#     entropy: 0
#
#     index: 4
#     name: normal
#     prob: 0
#     entropy: 0
#
#     index: 5
#     name: seasonal/variable
#     prob: 0
#     entropy: 0
#
#     index: 6
#     name: hard
#     prob: 0
#     entropy: 0
#
#
# name: sleep_amount
# type: ordinal
# num_cat: 4
# entropy: 0.821417751377399
# std_entropy: 1.3862943611198906
# reliability: 0.5925276582051685
#
#     index: 0
#     name: low
#     prob: 0.10276679841897234
#     entropy: 0.2338245720093162
#
#     index: 1
#     name: medium
#     prob: 0.7114624505928854
#     entropy: 0.24220503877753272
#
#     index: 2
#     name: high
#     prob: 0.17786561264822134
#     entropy: 0.3071253555457471
#
#     index: 3
#     name: variable
#     prob: 0.007905138339920948
#     entropy: 0.03826278504480296
#
#
# name: speaking_amount
# type: ordinal
# num_cat: 3
# entropy: 0.8665622497803226
# std_entropy: 1.0986122886681098
# reliability: 0.788778952064053
#
#     index: 0
#     name: less
#     prob: 0.11462450592885376
#     entropy: 0.24828741542881558
#
#     index: 1
#     name: moderate
#     prob: 0.6521739130434783
#     entropy: 0.2787678357566998
#
#     index: 2
#     name: excessive
#     prob: 0.233201581027668
#     entropy: 0.33950699859480726
#
#
# name: speaking_speed
# type: ordinal
# num_cat: 4
# entropy: 0.8051470943624687
# std_entropy: 1.3862943611198906
# reliability: 0.580790860111446
#
#     index: 0
#     name: slow
#     prob: 0.11904761904761904
#     entropy: 0.2533609173630081
#
#     index: 1
#     name: medium
#     prob: 0.7182539682539683
#     entropy: 0.23769326262084586
#
#     index: 2
#     name: quick
#     prob: 0.15873015873015872
#     entropy: 0.2921507354599186
#
#     index: 3
#     name: variable
#     prob: 0.003968253968253968
#     entropy: 0.021942178918696122
#
#
# name: stool_consistency
# type: ordinal
# num_cat: 3
# entropy: 0.5628243008646902
# std_entropy: 1.0986122886681098
# reliability: 0.5123047563458659
#
#     index: 0
#     name: loose/soft/semisolid
#     prob: 0.06374501992031872
#     entropy: 0.17548138434371333
#
#     index: 1
#     name: medium
#     prob: 0.8326693227091634
#     entropy: 0.15247731321871444
#
#     index: 2
#     name: hard
#     prob: 0.10358565737051793
#     entropy: 0.23486560330226236
#
#
# name: teeth_color
# type: ordinal
# num_cat: 3
# entropy: 0.9383402225938247
# std_entropy: 1.0986122886681098
# reliability: 0.8541140785266573
#
#     index: 0
#     name: milkywhite
#     prob: 0.4940239043824701
#     entropy: 0.3483715152084328
#
#     index: 1
#     name: yellowish
#     prob: 0.4103585657370518
#     entropy: 0.36551620295984566
#
#     index: 2
#     name: dull/blackish
#     prob: 0.09561752988047809
#     entropy: 0.22445250442554626
#
#
# name: teeth_size
# type: ordinal
# num_cat: 4
# entropy: 0.6216187276866127
# std_entropy: 1.3862943611198906
# reliability: 0.4484031278785916
#
#     index: 0
#     name: toosmall
#     prob: 0.05138339920948617
#     entropy: 0.15252854429429955
#
#     index: 1
#     name: medium
#     prob: 0.8063241106719368
#     entropy: 0.173576984016577
#
#     index: 2
#     name: large
#     prob: 0.1383399209486166
#     entropy: 0.27364209467720846
#
#     index: 3
#     name: toolarge
#     prob: 0.003952569169960474
#     entropy: 0.02187110469852775
#
#
# name: tongue_movements
# type: ordinal
# num_cat: 3
# entropy: 0.32089472577804246
# std_entropy: 1.0986122886681098
# reliability: 0.2920909670208364
#
#     index: 0
#     name: less
#     prob: 0.9090909090909091
#     entropy: 0.08664561800393172
#
#     index: 1
#     name: moderate
#     prob: 0.08695652173913043
#     entropy: 0.21237800307558297
#
#     index: 2
#     name: high/excessive
#     prob: 0.003952569169960474
#     entropy: 0.02187110469852775
#
#
# name: walking_amount
# type: ordinal
# num_cat: 3
# entropy: 0.7702937079452042
# std_entropy: 1.0986122886681098
# reliability: 0.7011515489955616
#
#     index: 0
#     name: less
#     prob: 0.09090909090909091
#     entropy: 0.21799047934530644
#
#     index: 1
#     name: moderate
#     prob: 0.7193675889328063
#     entropy: 0.23694731185941476
#
#     index: 2
#     name: high/excessive
#     prob: 0.18972332015810275
#     entropy: 0.315355916740483
#
#
# name: walking_speed
# type: ordinal
# num_cat: 4
# entropy: 0.960542943407307
# std_entropy: 1.3862943611198906
# reliability: 0.692885270507305
#
#     index: 0
#     name: slow
#     prob: 0.11857707509881422
#     entropy: 0.2528291036045887
#
#     index: 1
#     name: medium
#     prob: 0.5889328063241107
#     entropy: 0.3118064594250083
#
#     index: 2
#     name: quick/fast/brisk
#     prob: 0.2845849802371542
#     entropy: 0.357644595332907
#
#     index: 3
#     name: variable
#     prob: 0.007905138339920948
#     entropy: 0.03826278504480296
#
#
# name: walking_steps
# type: ordinal
# num_cat: 3
# entropy: 0.6315795109920384
# std_entropy: 1.0986122886681098
# reliability: 0.5748884456387491
#
#     index: 0
#     name: small
#     prob: 0.12350597609561753
#     entropy: 0.2583085170280708
#
#     index: 1
#     name: medium
#     prob: 0.8007968127490039
#     entropy: 0.1778954352414914
#
#     index: 2
#     name: large
#     prob: 0.07569721115537849
#     entropy: 0.1953755587224762
#
#
# name: working_speed
# type: ordinal
# num_cat: 4
# entropy: 0.8747841661058637
# std_entropy: 1.3862943611198906
# reliability: 0.6310233891445585
#
#     index: 0
#     name: slow
#     prob: 0.07114624505928854
#     entropy: 0.18804078717377234
#
#     index: 1
#     name: medium
#     prob: 0.6482213438735178
#     entropy: 0.28101890113891215
#
#     index: 2
#     name: quick/fast/brisk
#     prob: 0.26877470355731226
#     entropy: 0.3531381868833839
#
#     index: 3
#     name: variable
#     prob: 0.011857707509881422
#     entropy: 0.05258629090979538

# %% [markdown]
# ## Verdict: Working
#
# Now work on distance in file distance.py. You may start from scratch
