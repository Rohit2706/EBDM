# %% [markdown]
# # IMPORT DEPENDENCIES
# 1. Pandas
# 2. Math

# %%
import pandas as pd
import math

# %% [markdown]
# # CODE FROM PACKAGE

# %%
class Categories:
    """
    A class used to represent a category of a feature. A category represents a 
    choice given in a question.
    Attributes
    ----------
    name : str
        the name of the category
    index : int
        the index is used to identify the categories. It preserves the order of the 
        categories in case of ordinal features.
    prob : float
        the occurence probability of a category of a feature in a particular population
    entropy : float
        the entropy of a category of a feature in a particular population given by
        entropy = -p * log(p) where p is the occurence probability
        
    """
  
    def __init__(self, name, index):
        """
        Parameters
        ----------
        name : str
            the name of the category
        index : int
            the index is used to identify the categories. It preserves the order of the 
            categories in case of ordinal features.
        """

        self.name = name
        self.index = index
        self.prob = 0
        self.entropy = 0

# %%
def distance_between_categories(features):
    """
    Calculates the distance between all the categories for every feature.
    
    Parameters
    ----------
    features : dictionary
        a dictionary of features with keys as feature name and values as objects of
        feature class
     
    Returns
    -------
    features : dictionary
        a dictionary of features with keys as feature name and values as objects of
        feature class with updated distance values
    """
    
    for feat in features:
        for i in features[feat].category_order.keys():
            features[feat].distances[features[feat].category_order[i]] = dict()

    for feat in features:
        for i in features[feat].category_order.keys():
            features[feat].distances[features[feat].category_order[i]][features[feat].category_order[i]] = 0               
            
            if (features[feat].feat_type == 'ordinal'):
                for j in range(i+1, features[feat].num_cat):
                    prev = features[feat].distances[features[feat].category_order[i]][features[feat].category_order[j-1]]
                    curr = prev + (features[feat].weight)*(features[feat].categories[features[feat].category_order[j]].entropy)
                    
                    features[feat].distances[features[feat].category_order[i]][features[feat].category_order[j]] = curr
                    features[feat].distances[features[feat].category_order[j]][features[feat].category_order[i]] = curr
            else:
                for j in range(i+1, features[feat].num_cat):
                    curr = (features[feat].weight)*(features[feat].categories[features[feat].category_order[j]].entropy + features[feat].categories[features[feat].category_order[i]].entropy) 
                    
                    features[feat].distances[features[feat].category_order[i]][features[feat].category_order[j]] = curr 
                    features[feat].distances[features[feat].category_order[j]][features[feat].category_order[i]] = curr
                    
    return features
    

def distance_between_individuals(data, features):
    """
    Calculates the distance between individuals of a population
    
    Parameters
    ----------
    df : panda dataframe
        the dataset of the population in the format:
                 | Feedback  |  Color  |   Hobby  
        ------------------------------------------
        Person A |   Poor    |   Red   |  Football
                
    features : dictionary
        a dictionary of features with keys as feature name and values as objects of
        feature class.
     
    Returns
    -------
    dist_mat : list
        a list of lists representing the pairwise distance matrix of the individuals
    """
    
    dist_mat = []
    
    for index1 in data.index:
        
        dist_temp = []
        for index2 in data.index: 
            
            dist = 0
            for col in data.columns:     
                
                if (type(data.loc[index1,col]) == str and type(data.loc[index2,col]) == str):
                    dist += (features[col].distances[data.loc[index1,col]][data.loc[index2,col]])**2
            
            dist_temp.append(math.sqrt(dist))
        
        dist_mat.append(dist_temp)
            
    dist_mat = pd.DataFrame(dist_mat)    
    
    return dist_mat

# %%
def probability(df, features):
    """
    Calculates the occurence probability of all the categories for every feature.
    
    Parameters
    ----------
    df : panda dataframe
        the dataset of the population
        
    features : dictionary
        a dictionary of features with keys as feature name and values as objects of
        feature class.
        
    Returns
    -------
    features : dictionary
        a dictionary of features with keys as feature name and values as objects of
        feature class with updated probability values.
    """
    
    for feat in features.keys():
        series = df[feat].value_counts(normalize=True,sort=False)
        for cat in series.index:
            features[feat].categories[cat].prob = series[cat]

    return features

def entropy(features):
    """
    Calculates the entropy of all the categories for every feature.
    
    Parameters
    ----------
    features : dictionary
        a dictionary of features with keys as feature name and values as objects of
        feature class.
     
    Returns
    -------
    features : dictionary
        a dictionary of features with keys as feature name and values as objects of
        feature class with updated entropy values.
    """
    
    for feat in features.values():
        for cat in feat.categories.values():
            if(cat.prob):
                cat.entropy = (-1)*cat.prob*math.log(cat.prob)
            else:
                pass

    return features


def std_entropy(features):
    """
    Calculates the standard entropy of all the features.
    
    Parameters
    ----------
    features : dictionary
        a dictionary of features with keys as feature name and values as objects of
        feature class.
     
    Returns
    -------
    features : dictionary
        a dictionary of features with keys as feature name and values as objects of
        feature class with updated standard entropy values.
    """
    
    for feat in features.values():
        if(feat.num_cat):
            feat.std_entropy = math.log(feat.num_cat)
        else:
            pass

    return features

def feature_entropy(features):
    """
    Calculates the entropy of all the features.
    
    Parameters
    ----------
    features : dictionary
        a dictionary of features with keys as feature name and values as objects of
        feature class.
     
    Returns
    -------
    features : dictionary
        a dictionary of features with keys as feature name and values as objects of
        feature class with updated feature entropy values.
    """
    
    for feat in features.values():
        feat_entropy = 0
        for cat in feat.categories.values():
            feat_entropy = feat_entropy + cat.entropy

        feat.entropy = feat_entropy

    return features

def reliability(features):
    """
    Calculates the reliability of all the features.
    
    Parameters
    ----------
    features : dictionary
        a dictionary of features with keys as feature name and values as objects of
        feature class.
     
    Returns
    -------
    features : dictionary
        a dictionary of features with keys as feature name and values as objects of
        feature class with updated reliability values.
    """
    
    for feat in features.values():
        try:
            feat.reliability = feat.entropy/ feat.std_entropy
        except ZeroDivisionError as error:
            Logging.log_exception(error)

    return features

def total_reliability(features):
    """
    Calculates the total reliability of the features.
    
    Parameters
    ----------
    features : dictionary
        a dictionary of features with keys as feature name and values as objects of
        feature class.
     
    Returns
    -------
    total_rel : float
        the total reliability of the features
    """
    
    total_rel = 0
    for feat in features.values():
        total_rel = total_rel + feat.reliability

    return total_rel

def weights(features, total_reliability):
    """
    Calculates the weights of all the features.
    
    Parameters
    ----------
    features : dictionary
        a dictionary of features with keys as feature name and values as objects of
        feature class.
    total_reliability : float
        the total reliability of the features
        
    Returns
    -------
    features : dictionary
        a dictionary of features with keys as feature name and values as objects of
        feature class with updated weight values.
    """
    
    for feat in features:
        features[feat].weight = features[feat].reliability/ total_reliability

    return features

# %%
class Features:
    """
    A class used to represent a feature. A feature represents question asked in the
    questionnaire.
    ...
    Attributes
    ----------
    name : str
        the name of the feature
    feat_type : str
        the type of feature: ordinal or nominal
    num_cat : int
        the number of categories for a feature in the questionnaire
    categories : dictionary
        a dictionary with keys as category name and values as objects of Categories class
    entropy : float
        the entropy of a feature in a particular population, given by
        entropy of feature = sum(entropy of categories)
    std_entropy : float
        the standard entropy of a feature given by log(num_cat)
    reliability : float
        the reliability of a feature given by entropy/ std_entropy
    weight : float
        the weight of a feature given by reliability/ total_reliability
    distance : dictionary
        the dictionary of distances between categories of a feature.
        distance[cat1][cat2] represents distance between cat1 and cat2
    category_order : dictionary
        the dictionary from category index to category name
        
    """
    
    def __init__(self, name, feat_type):
        """
        Parameters
        ----------
        name : str
            the name of the feature
        feat_type : str
            the type of feature: ordinal or nominal
        """
        
        self.name = name
        self.feat_type = feat_type
        self.num_cat = 0
        self.categories = dict()
        self.entropy = 0
        self.std_entropy = 0
        self.reliability = 0
        self.weight = 0
        self.distance = dict()
        self.category_order = dict()

# %%
def read_nom(data):
    """
    Reads the nominal data from the data file and instantiate the Features and
    Categories classes.
    
    Parameters
    ----------
    data : str
        The file location of the spreadsheet containing nominal categories in the format:
        Feature  | Category1 | Category2 | Category3.........
        ----------------------------------------------------
        Color    |    Red    |    Blue   |  Green
                 '           '           '
                 '           '           '
                 
    Returns
    -------
    features : dictionary
        a dictionary of features with keys as feature name and values as objects of
        feature class.
    """
    
    try:
        nominal_categories = pd.read_csv(data,header=None,index_col=0)
    except ImportError:
        print('Error Importing Nominal Data')

    features = dict()
    
    for feat in nominal_categories.index:
        feat_instance = Features(feat,'nominal')
        
        cat_names = nominal_categories.loc[feat,nominal_categories.loc[feat,:].notnull()].tolist()
        feat_instance.num_cat = len(cat_names)
        
        for _index, _name in enumerate(cat_names):
            feat_instance.categories[_name] = Categories(_name, _index)
            feat_instance.category_order[_index] = _name
           
        features[feat] = feat_instance
        
    return features

# %%
def read_ord(data):
    """
    Reads the ordinal data from the data file and instantiate the Features and
    Categories classes.
    Parameters
    ----------
    data : str
        The file location of the spreadsheet containing ordinal categories in the format:
        Feature  | Category1 | Category2 | Category3.........
        ----------------------------------------------------
        Feedback |   Poor    |    Good   |  Excellent
                 '           '           '
                 '           '           '
                 
    Returns
    -------
    features : dictionary
        a dictionary of features with keys as feature name and values as objects of
        feature class.
    """
    
    try:
        ordinal_categories = pd.read_csv(data,header=None,index_col=0)
    except ImportError:
        print('Error Importing Ordinal Data')

    features = dict()
    
    for feat in ordinal_categories.index:
        feat_instance = Features(feat,'ordinal')
        
        cat_names = ordinal_categories.loc[feat,ordinal_categories.loc[feat,:].notnull()].tolist()
        feat_instance.num_cat = len(cat_names)
        
        for _index, _name in enumerate(cat_names):
            feat_instance.categories[_name] = Categories(_name, _index)
            feat_instance.category_order[_index] = _name
           
        features[feat] = feat_instance
        
    return features

# %% [markdown]
# # PREPROCESSING
#
# Random code. Don't refer!

# %% [markdown]
# https://www.kaggle.com/xiaowenlimarketing/international-student-time-management

# %%
df = pd.read_csv('International students Time management data.csv', index_col=0)

# %%
df
# Out:
#           Age Gender          Nationality Program  \
# Number
# 1       31-35      M                Korea      PM
# 2       26-30      M                China      PM
# 3       26-30      M                Kenya      PM
# 4       21-25      M              Vietnam      PM
# 5       21-25      M                China      PM
# 6       21-25      M                China      PM
# 7       21-25      M                China      PM
# 8       21-25      M                China      PM
# 9       21-25      M                China      PM
# 10      21-25      M                China      PM
# 11      21-25      M                China      PM
# 12      18-20      M                China     IYO
# 13      18-20      M                China     IYO
# 14      18-20      M                India     IYO
# 15      18-20      M         Saudi Arabia      FC
# 16      18-20      M                China      FC
# 17        >36      M                Korea      PM
# 18        <18      M         Saudi Arabia      FC
# 19        <18      M             Tanzania      FC
# 20        <18      M                China      FC
# 21      18-20      M                 Oman      FC
# 22      18-20      M               Jordan      FC
# 23      18-20      M             Zimbabwe      FC
# 24      18-20      M                 Oman      FC
# 25      18-20      M             Portugal      FC
# 26      18-20      M                 Oman      FC
# 27      18-20      M                China      FC
# 28        <18      M              Georgia     IYO
# 29      18-20      M                China     IYO
# 30      18-20      M                India     IYO
# ...       ...    ...                  ...     ...
# 96      21-25      F                China      PM
# 97      21-25      F                Korea      PM
# 98      21-25      F                China      PM
# 99      21-25      F                China      PM
# 100     21-25      F                China      PM
# 101     21-25      F                China      PM
# 102     21-25      F  Trinidad and Tobago      PM
# 103     21-25      F                China      PM
# 104     21-25      F                China      PM
# 105     21-25      F                China      PM
# 106     21-25      F                China      PM
# 107     21-25      F                China      PM
# 108     21-25      F                China      PM
# 109     21-25      F                China      PM
# 110     21-25      F                China      PM
# 111     21-25      F                China      PM
# 112     31-35      F                Korea      PM
# 113       >36      F             Colombia     IYO
# 114     21-25      F                China      PM
# 115     18-20      F                China      PM
# 116     21-25      M                China      PM
# 117     21-25      M                China      PM
# 118     21-25      M                China      PM
# 119     21-25      F                China      PM
# 120     21-25      M                China      PM
# 121     21-25      M                China      PM
# 122     31-35      F                China      PM
# 123     26-30      M                Gongo      PM
# 124     21-25      F              Ukraine      PM
# 125     26-30      F                Korea      PM
#
#                                 Course  English Academic Attendance  \
# Number
# 1       Social Sciences and Humanities  60%~70%      NaN         S0
# 2              Science and engineering  60%~70%  50%~59%         S3
# 3                             Business  60%~70%      NaN         S0
# 4                    Law/Legal studies  60%~70%  60%~70%         S0
# 5                             Business  60%~70%  50%~59%         S1
# 6                    Law/Legal studies  60%~70%  60%~70%         S0
# 7                       Art and Design  60%~70%  60%~70%         S0
# 8                             Business  60%~70%      NaN         S0
# 9                            Computing  60%~70%  40%~49%         S0
# 10                           Computing  60%~70%     >70%         S0
# 11                            Business  60%~70%     >70%         S1
# 12                            Business  60%~70%  50%~59%         S1
# 13                            Business  60%~70%  60%~70%         S3
# 14                            Business  60%~70%  60%~70%         S2
# 15                            Business     >70%  60%~70%         S1
# 16                            Business     >70%     >70%         S1
# 17                   Law/Legal studies     >70%      NaN         S0
# 18                           Computing     >70%  60%~70%         S0
# 19                            Business  60%~70%  60%~70%         S0
# 20                            Business  60%~70%  60%~70%         S0
# 21      Social Sciences and Humanities  60%~70%     >70%         S4
# 22            Media and Communications  60%~70%  60%~70%         S0
# 23                      Art and Design  60%~70%     >70%         S0
# 24      Social Sciences and Humanities  60%~70%      NaN         S0
# 25                            Business  60%~70%  50%~59%         S3
# 26                   Law/Legal studies  60%~70%      NaN         S0
# 27                            Business  60%~70%  60%~70%         S2
# 28                            Business  60%~70%  50%~59%         S3
# 29                            Business  60%~70%  50%~59%         S1
# 30                            Business  60%~70%  60%~70%         S2
# ...                                ...      ...      ...        ...
# 96                            Business  50%~59%  50%~59%         S1
# 97                            Business      NaN      NaN        NaN
# 98                            Business  60%~70%  60%~70%         S0
# 99                            Business  50%~59%  50%~59%         S0
# 100                           Business      NaN      NaN        NaN
# 101                           Business     >70%  60%~70%         S4
# 102     Social Sciences and Humanities     >70%     >70%         S2
# 103                           Business  50%~59%  50%~59%         S1
# 104                           Business  50%~59%  60%~70%         S0
# 105                           Business  50%~59%  50%~59%         S0
# 106                           Business  60%~70%  60%~70%         S0
# 107                           Business  60%~70%  60%~70%         S0
# 108                           Business  60%~70%  50%~59%         S0
# 109                           Business  40%~49%      NaN         S0
# 110                           Business  60%~70%  60%~70%         S0
# 111                  Law/Legal studies      NaN      NaN        NaN
# 112     Social Sciences and Humanities      NaN      NaN        NaN
# 113     Social Sciences and Humanities  40%~49%  40%~49%         S3
# 114                           Business  50%~59%  60%~70%         S0
# 115                           Business  50%~59%  50%~59%         S0
# 116                           Business  60%~70%  50%~59%         S1
# 117                           Business  60%~70%  60%~70%         S0
# 118                           Business  60%~70%  50%~59%         S0
# 119                           Business  50%~59%  60%~70%         S0
# 120                           Business  50%~59%  40%~49%         S3
# 121                           Business  60%~70%  50%~59%         S1
# 122                           Business  50%~59%  50%~59%         S1
# 123                           Business     >70%  60%~70%         S0
# 124                           Business  60%~70%  60%~70%         S1
# 125                           Business  60%~70%     >70%         S0
#
#        You often feel that your life is aimless, with no definite purpose  \
# Number
# 1                                                Disagree
# 2                                            Strong Agree
# 3                                                Disagree
# 4                                                Disagree
# 5                                                 Neither
# 6                                                   Agree
# 7                                                Disagree
# 8                                                   Agree
# 9                                                Disagree
# 10                                        Strong Disagree
# 11                                        Strong Disagree
# 12                                                Neither
# 13                                               Disagree
# 14                                                  Agree
# 15                                               Disagree
# 16                                           Strong Agree
# 17                                                Neither
# 18                                               Disagree
# 19                                               Disagree
# 20                                                  Agree
# 21                                           Strong Agree
# 22                                               Disagree
# 23                                               Disagree
# 24                                               Disagree
# 25                                                  Agree
# 26                                                    NaN
# 27                                                Neither
# 28                                           Strong Agree
# 29                                        Strong Disagree
# 30                                                Neither
# ...                                                   ...
# 96                                               Disagree
# 97                                               Disagree
# 98                                               Disagree
# 99                                                  Agree
# 100                                              Disagree
# 101                                       Strong Disagree
# 102                                               Neither
# 103                                              Disagree
# 104                                              Disagree
# 105                                              Disagree
# 106                                              Disagree
# 107                                              Disagree
# 108                                               Neither
# 109                                                 Agree
# 110                                               Neither
# 111                                       Strong Disagree
# 112                                          Strong Agree
# 113                                               Neither
# 114                                              Disagree
# 115                                               Neither
# 116                                       Strong Disagree
# 117                                              Disagree
# 118                                              Disagree
# 119                                              Disagree
# 120                                               Neither
# 121                                              Disagree
# 122                                                 Agree
# 123                                       Strong Disagree
# 124                                                 Agree
# 125                                              Disagree
#
#        You never have trouble organizing the things you have to do?  \
# Number
# 1                                                   Agree
# 2                                                   Agree
# 3                                            Strong Agree
# 4                                                Disagree
# 5                                                Disagree
# 6                                                 Neither
# 7                                                   Agree
# 8                                                 Neither
# 9                                                Disagree
# 10                                                  Agree
# 11                                                Neither
# 12                                               Disagree
# 13                                                Neither
# 14                                                  Agree
# 15                                                  Agree
# 16                                           Strong Agree
# 17                                               Disagree
# 18                                               Disagree
# 19                                               Disagree
# 20                                                  Agree
# 21                                                  Agree
# 22                                                Neither
# 23                                               Disagree
# 24                                               Disagree
# 25                                           Strong Agree
# 26                                                Neither
# 27                                                  Agree
# 28                                                  Agree
# 29                                                  Agree
# 30                                                Neither
# ...                                                   ...
# 96                                                  Agree
# 97                                                  Agree
# 98                                        Strong Disagree
# 99                                           Strong Agree
# 100                                                 Agree
# 101                                          Strong Agree
# 102                                              Disagree
# 103                                               Neither
# 104                                               Neither
# 105                                       Strong Disagree
# 106                                                 Agree
# 107                                               Neither
# 108                                              Disagree
# 109                                              Disagree
# 110                                              Disagree
# 111                                              Disagree
# 112                                              Disagree
# 113                                               Neither
# 114                                              Disagree
# 115                                                 Agree
# 116                                               Neither
# 117                                                 Agree
# 118                                              Disagree
# 119                                              Disagree
# 120                                               Neither
# 121                                              Disagree
# 122                                              Disagree
# 123                                               Neither
# 124                                              Disagree
# 125                                       Strong Disagree
#
#        Once you've started an activity, you persist at it until you've completed it  \
# Number
# 1                                            Strong Agree
# 2                                                 Neither
# 3                                                   Agree
# 4                                                   Agree
# 5                                                 Neither
# 6                                                   Agree
# 7                                                   Agree
# 8                                                 Neither
# 9                                         Strong Disagree
# 10                                                  Agree
# 11                                                Neither
# 12                                                Neither
# 13                                                Neither
# 14                                                  Agree
# 15                                               Disagree
# 16                                                  Agree
# 17                                                  Agree
# 18                                                Neither
# 19                                                  Agree
# 20                                           Strong Agree
# 21                                           Strong Agree
# 22                                                Neither
# 23                                               Disagree
# 24                                                Neither
# 25                                                Neither
# 26                                                  Agree
# 27                                                Neither
# 28                                               Disagree
# 29                                                  Agree
# 30                                                Neither
# ...                                                   ...
# 96                                                  Agree
# 97                                           Strong Agree
# 98                                           Strong Agree
# 99                                                  Agree
# 100                                                 Agree
# 101                                          Strong Agree
# 102                                               Neither
# 103                                                   NaN
# 104                                                 Agree
# 105                                              Disagree
# 106                                              Disagree
# 107                                                 Agree
# 108                                                 Agree
# 109                                                 Agree
# 110                                                 Agree
# 111                                              Disagree
# 112                                               Neither
# 113                                               Neither
# 114                                                 Agree
# 115                                          Strong Agree
# 116                                          Strong Agree
# 117                                                 Agree
# 118                                                 Agree
# 119                                                 Agree
# 120                                              Disagree
# 121                                                 Agree
# 122                                               Neither
# 123                                               Neither
# 124                                              Disagree
# 125                                                 Agree
#
#        Sometimes you feel that the things you have to do during the day just don't seem to matter  \
# Number
# 1                                                 Neither
# 2                                                Disagree
# 3                                                Disagree
# 4                                                   Agree
# 5                                                 Neither
# 6                                            Strong Agree
# 7                                                 Neither
# 8                                                   Agree
# 9                                                   Agree
# 10                                                Neither
# 11                                                Neither
# 12                                                Neither
# 13                                                Neither
# 14                                                  Agree
# 15                                                  Agree
# 16                                                Neither
# 17                                                  Agree
# 18                                                  Agree
# 19                                               Disagree
# 20                                                  Agree
# 21                                                Neither
# 22                                                Neither
# 23                                                  Agree
# 24                                               Disagree
# 25                                                  Agree
# 26                                               Disagree
# 27                                                  Agree
# 28                                        Strong Disagree
# 29                                                Neither
# 30                                                Neither
# ...                                                   ...
# 96                                                    NaN
# 97                                                Neither
# 98                                               Disagree
# 99                                                Neither
# 100                                                   NaN
# 101                                       Strong Disagree
# 102                                                 Agree
# 103                                               Neither
# 104                                               Neither
# 105                                                   NaN
# 106                                               Neither
# 107                                                 Agree
# 108                                               Neither
# 109                                              Disagree
# 110                                                 Agree
# 111                                               Neither
# 112                                                 Agree
# 113                                               Neither
# 114                                              Disagree
# 115                                               Neither
# 116                                                 Agree
# 117                                               Neither
# 118                                                 Agree
# 119                                               Neither
# 120                                                 Agree
# 121                                               Neither
# 122                                                 Agree
# 123                                               Neither
# 124                                          Strong Agree
# 125                                                 Agree
#
#        You will plan your activities from day to day.  \
# Number
# 1                                               Agree
# 2                                               Agree
# 3                                               Agree
# 4                                            Disagree
# 5                                            Disagree
# 6                                            Disagree
# 7                                               Agree
# 8                                               Agree
# 9                                            Disagree
# 10                                           Disagree
# 11                                            Neither
# 12                                       Strong Agree
# 13                                           Disagree
# 14                                            Neither
# 15                                    Strong Disagree
# 16                                       Strong Agree
# 17                                            Neither
# 18                                            Neither
# 19                                       Strong Agree
# 20                                       Strong Agree
# 21                                           Disagree
# 22                                              Agree
# 23                                           Disagree
# 24                                            Neither
# 25                                            Neither
# 26                                           Disagree
# 27                                           Disagree
# 28                                    Strong Disagree
# 29                                              Agree
# 30                                            Neither
# ...                                               ...
# 96                                              Agree
# 97                                       Strong Agree
# 98                                              Agree
# 99                                              Agree
# 100                                             Agree
# 101                                      Strong Agree
# 102                                             Agree
# 103                                           Neither
# 104                                             Agree
# 105                                             Agree
# 106                                             Agree
# 107                                             Agree
# 108                                             Agree
# 109                                             Agree
# 110                                             Agree
# 111                                             Agree
# 112                                           Neither
# 113                                           Neither
# 114                                           Neither
# 115                                             Agree
# 116                                           Neither
# 117                                             Agree
# 118                                             Agree
# 119                                             Agree
# 120                                           Neither
# 121                                          Disagree
# 122                                           Neither
# 123                                           Neither
# 124                                          Disagree
# 125                                             Agree
#
#        You tend to leave things to the last minute?  \
# Number
# 1                                           Neither
# 2                                           Neither
# 3                                             Agree
# 4                                             Agree
# 5                                           Neither
# 6                                          Disagree
# 7                                           Neither
# 8                                           Neither
# 9                                             Agree
# 10                                  Strong Disagree
# 11                                          Neither
# 12                                            Agree
# 13                                         Disagree
# 14                                          Neither
# 15                                         Disagree
# 16                                     Strong Agree
# 17                                         Disagree
# 18                                  Strong Disagree
# 19                                         Disagree
# 20                                     Strong Agree
# 21                                          Neither
# 22                                            Agree
# 23                                            Agree
# 24                                         Disagree
# 25                                          Neither
# 26                                          Neither
# 27                                            Agree
# 28                                  Strong Disagree
# 29                                            Agree
# 30                                         Disagree
# ...                                             ...
# 96                                              NaN
# 97                                  Strong Disagree
# 98                                         Disagree
# 99                                         Disagree
# 100                                        Disagree
# 101                                        Disagree
# 102                                        Disagree
# 103                                         Neither
# 104                                 Strong Disagree
# 105                                        Disagree
# 106                                           Agree
# 107                                        Disagree
# 108                                         Neither
# 109                                           Agree
# 110                                           Agree
# 111                                           Agree
# 112                                    Strong Agree
# 113                                         Neither
# 114                                        Disagree
# 115                                 Strong Disagree
# 116                                        Disagree
# 117                                         Neither
# 118                                           Agree
# 119                                           Agree
# 120                                           Agree
# 121                                        Disagree
# 122                                    Strong Agree
# 123                                         Neither
# 124                                           Agree
# 125                                 Strong Disagree
#
#        You tend to change rather aimlessly from one activity to another during the day.  \
# Number
# 1                                                Disagree
# 2                                                Disagree
# 3                                                Disagree
# 4                                                 Neither
# 5                                                 Neither
# 6                                            Strong Agree
# 7                                                 Neither
# 8                                                   Agree
# 9                                                   Agree
# 10                                        Strong Disagree
# 11                                                Neither
# 12                                                Neither
# 13                                               Disagree
# 14                                                  Agree
# 15                                           Strong Agree
# 16                                                  Agree
# 17                                               Disagree
# 18                                                Neither
# 19                                               Disagree
# 20                                                  Agree
# 21                                                  Agree
# 22                                                  Agree
# 23                                                  Agree
# 24                                           Strong Agree
# 25                                               Disagree
# 26                                                Neither
# 27                                                Neither
# 28                                               Disagree
# 29                                                  Agree
# 30                                                Neither
# ...                                                   ...
# 96                                                Neither
# 97                                                  Agree
# 98                                               Disagree
# 99                                           Strong Agree
# 100                                               Neither
# 101                                       Strong Disagree
# 102                                               Neither
# 103                                               Neither
# 104                                                 Agree
# 105                                                 Agree
# 106                                              Disagree
# 107                                              Disagree
# 108                                                 Agree
# 109                                                 Agree
# 110                                               Neither
# 111                                               Neither
# 112                                                 Agree
# 113                                               Neither
# 114                                              Disagree
# 115                                              Disagree
# 116                                               Neither
# 117                                               Neither
# 118                                               Neither
# 119                                                 Agree
# 120                                              Disagree
# 121                                               Neither
# 122                                                 Agree
# 123                                               Neither
# 124                                                 Agree
# 125                                              Disagree
#
#        You give up the things that you planning to do just because your friend says no.  \
# Number
# 1                                         Strong Disagree
# 2                                         Strong Disagree
# 3                                         Strong Disagree
# 4                                                 Neither
# 5                                                 Neither
# 6                                                   Agree
# 7                                         Strong Disagree
# 8                                                 Neither
# 9                                                Disagree
# 10                                        Strong Disagree
# 11                                                Neither
# 12                                               Disagree
# 13                                               Disagree
# 14                                                Neither
# 15                                        Strong Disagree
# 16                                           Strong Agree
# 17                                               Disagree
# 18                                                  Agree
# 19                                                  Agree
# 20                                           Strong Agree
# 21                                               Disagree
# 22                                               Disagree
# 23                                        Strong Disagree
# 24                                        Strong Disagree
# 25                                           Strong Agree
# 26                                        Strong Disagree
# 27                                                Neither
# 28                                        Strong Disagree
# 29                                                  Agree
# 30                                                Neither
# ...                                                   ...
# 96                                               Disagree
# 97                                               Disagree
# 98                                        Strong Disagree
# 99                                               Disagree
# 100                                              Disagree
# 101                                              Disagree
# 102                                       Strong Disagree
# 103                                       Strong Disagree
# 104                                               Neither
# 105                                              Disagree
# 106                                              Disagree
# 107                                              Disagree
# 108                                               Neither
# 109                                              Disagree
# 110                                               Neither
# 111                                              Disagree
# 112                                       Strong Disagree
# 113                                               Neither
# 114                                       Strong Disagree
# 115                                       Strong Disagree
# 116                                              Disagree
# 117                                              Disagree
# 118                                       Strong Disagree
# 119                                              Disagree
# 120                                               Neither
# 121                                              Disagree
# 122                                                 Agree
# 123                                       Strong Disagree
# 124                                       Strong Disagree
# 125                                       Strong Disagree
#
#        You think you do enough with your time.  \
# Number
# 1                                 Strong Agree
# 2                                      Neither
# 3                                     Disagree
# 4                                      Neither
# 5                                      Neither
# 6                                 Strong Agree
# 7                                     Disagree
# ...
# 27                             Strong Disagree
# 28                                       Agree
# 29                                       Agree
# 30                                     Neither
# ...                                        ...
# 96                                    Disagree
# 97                                     Neither
# 98                                       Agree
# 99                                       Agree
# 100                                    Neither
# 101                               Strong Agree
# 102                               Strong Agree
# 103                                    Neither
# 104                                      Agree
# 105                                      Agree
# 106                                    Neither
# 107                                      Agree
# 108                                   Disagree
# 109                                    Neither
# 110                                   Disagree
# 111                                   Disagree
# 112                                   Disagree
# 113                                    Neither
# 114                                   Disagree
# 115                                    Neither
# 116                                   Disagree
# 117                                    Neither
# 118                                      Agree
# 119                                    Neither
# 120                                    Neither
# 121                                   Disagree
# 122                                   Disagree
# 123                                   Disagree
# 124                                   Disagree
# 125                                      Agree
#
#        You are easy to get bored with your day-today activities.  \
# Number
# 1                                                 Neither
# 2                                                   Agree
# 3                                            Strong Agree
# 4                                                 Neither
# 5                                                Disagree
# 6                                            Strong Agree
# 7                                         Strong Disagree
# 8                                                   Agree
# 9                                                Disagree
# 10                                                  Agree
# 11                                                Neither
# 12                                                  Agree
# 13                                               Disagree
# 14                                                Neither
# 15                                                Neither
# 16                                                Neither
# 17                                               Disagree
# 18                                           Strong Agree
# 19                                               Disagree
# 20                                                  Agree
# 21                                               Disagree
# 22                                                  Agree
# 23                                                  Agree
# 24                                               Disagree
# 25                                                Neither
# 26                                                Neither
# 27                                           Strong Agree
# 28                                                Neither
# 29                                                  Agree
# 30                                                  Agree
# ...                                                   ...
# 96                                               Disagree
# 97                                               Disagree
# 98                                                  Agree
# 99                                                Neither
# 100                                              Disagree
# 101                                       Strong Disagree
# 102                                               Neither
# 103                                               Neither
# 104                                              Disagree
# 105                                              Disagree
# 106                                               Neither
# 107                                                 Agree
# 108                                                 Agree
# 109                                       Strong Disagree
# 110                                                 Agree
# 111                                              Disagree
# 112                                              Disagree
# 113                                               Neither
# 114                                                 Agree
# 115                                               Neither
# 116                                               Neither
# 117                                              Disagree
# 118                                                 Agree
# 119                                              Disagree
# 120                                       Strong Disagree
# 121                                                 Agree
# 122                                                 Agree
# 123                                          Strong Agree
# 124                                          Strong Agree
# 125                                               Neither
#
#        The important interests/activities in your life tend to change frequently.  \
# Number
# 1                                                Disagree
# 2                                                 Neither
# 3                                            Strong Agree
# 4                                                Disagree
# 5                                                 Neither
# 6                                         Strong Disagree
# 7                                         Strong Disagree
# 8                                                   Agree
# 9                                                Disagree
# 10                                        Strong Disagree
# 11                                                Neither
# 12                                                Neither
# 13                                                  Agree
# 14                                                  Agree
# 15                                                  Agree
# 16                                                  Agree
# 17                                               Disagree
# 18                                                Neither
# 19                                                  Agree
# 20                                                  Agree
# 21                                                Neither
# 22                                                  Agree
# 23                                                  Agree
# 24                                               Disagree
# 25                                           Strong Agree
# 26                                                Neither
# 27                                                Neither
# 28                                           Strong Agree
# 29                                                  Agree
# 30                                                Neither
# ...                                                   ...
# 96                                        Strong Disagree
# 97                                               Disagree
# 98                                               Disagree
# 99                                                Neither
# 100                                              Disagree
# 101                                                 Agree
# 102                                                 Agree
# 103                                               Neither
# 104                                                 Agree
# 105                                                 Agree
# 106                                              Disagree
# 107                                               Neither
# 108                                                 Agree
# 109                                               Neither
# 110                                               Neither
# 111                                               Neither
# 112                                              Disagree
# 113                                               Neither
# 114                                              Disagree
# 115                                               Neither
# 116                                                 Agree
# 117                                                 Agree
# 118                                          Strong Agree
# 119                                               Neither
# 120                                              Disagree
# 121                                               Neither
# 122                                          Strong Agree
# 123                                              Disagree
# 124                                              Disagree
# 125                                              Disagree
#
#        You know how much time you spend on each of the homework I do.
# Number
# 1                                                   Agree
# 2                                                Disagree
# 3                                                Disagree
# 4                                                   Agree
# 5                                                   Agree
# 6                                            Strong Agree
# 7                                                 Neither
# 8                                                   Agree
# 9                                                Disagree
# 10                                        Strong Disagree
# 11                                                Neither
# 12                                                  Agree
# 13                                                  Agree
# 14                                                  Agree
# 15                                               Disagree
# 16                                                Neither
# 17                                                Neither
# 18                                                Neither
# 19                                                Neither
# 20                                                  Agree
# 21                                                Neither
# 22                                                  Agree
# 23                                               Disagree
# 24                                                  Agree
# 25                                               Disagree
# 26                                                  Agree
# 27                                        Strong Disagree
# 28                                        Strong Disagree
# 29                                                  Agree
# 30                                                Neither
# ...                                                   ...
# 96                                               Disagree
# 97                                                  Agree
# 98                                               Disagree
# 99                                                  Agree
# 100                                                 Agree
# 101                                          Strong Agree
# 102                                                 Agree
# 103                                               Neither
# 104                                               Neither
# 105                                              Disagree
# 106                                                 Agree
# 107                                                 Agree
# 108                                                 Agree
# 109                                                 Agree
# 110                                              Disagree
# 111                                              Disagree
# 112                                       Strong Disagree
# 113                                               Neither
# 114                                                 Agree
# 115                                                 Agree
# 116                                                 Agree
# 117                                               Neither
# 118                                          Strong Agree
# 119                                                 Agree
# 120                                               Neither
# 121                                                 Agree
# 122                                                 Agree
# 123                                               Neither
# 124                                              Disagree
# 125                                          Strong Agree
#
# [125 rows x 20 columns]

# %%
d = pd.DataFrame(df.columns)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-9def96d65662> in <module>
# ----> 1 d = pd.DataFrame(df.columns, header=None)
#
# TypeError: __init__() got an unexpected keyword argument 'header'

# %%
d.index = d[0]

# %%
d.drop(0,axis=1,inplace = True)

# %%
d.to_csv('preprocessed test data.csv')

# %%
df['Nationality'].unique()
# Out:
# array(['Korea', 'China', 'Kenya', 'Vietnam', 'India', 'Saudi Arabia',
#        'Tanzania', 'Oman', 'Jordan', 'Zimbabwe', 'Portugal', 'Georgia',
#        'Singapore', 'Malaysia', 'Qatar', 'Turkey', 'Kuwait', 'OCEAN',
#        'UK', 'Pakistan', 'Thailand', 'Indonesia', 'Trinidad and Tobago',
#        'Colombia', 'Gongo', 'Ukraine'], dtype=object)

# %%
row = []
for col in df:
    row.append(df[col].unique().tolist())

# %%
d = pd.DataFrame(row, index=df.columns)

# %%
d.to_csv('preprocessed test data.csv')

# %%
d = pd.read_csv('preprocessed test data ordinal.csv',header=None, index_col=0)

# %%
d
# Out:
#                                                                   1         2  \
# 0
# You often feel that your life is aimless, with ...  Strong Disagree  Disagree
# You never have trouble organizing the things yo...  Strong Disagree  Disagree
# Once you've started an activity, you persist at...  Strong Disagree  Disagree
# Sometimes you feel that the things you have to ...  Strong Disagree  Disagree
# You will plan your activities from day to day.      Strong Disagree  Disagree
# You tend to leave things to the last minute?        Strong Disagree  Disagree
# You tend to change rather aimlessly from one ac...  Strong Disagree  Disagree
# You give up the things that you planning to do ...  Strong Disagree  Disagree
# You think you do enough with your time.             Strong Disagree  Disagree
# You are easy to get bored with your day-today a...  Strong Disagree  Disagree
# The important interests/activities in your life...  Strong Disagree  Disagree
# You know how much time you spend on each of the...  Strong Disagree  Disagree
#
#                                                           3      4  \
# 0
# You often feel that your life is aimless, with ...  Neither  Agree
# You never have trouble organizing the things yo...  Neither  Agree
# Once you've started an activity, you persist at...  Neither  Agree
# Sometimes you feel that the things you have to ...  Neither  Agree
# You will plan your activities from day to day.      Neither  Agree
# You tend to leave things to the last minute?        Neither  Agree
# You tend to change rather aimlessly from one ac...  Neither  Agree
# You give up the things that you planning to do ...  Neither  Agree
# You think you do enough with your time.             Neither  Agree
# You are easy to get bored with your day-today a...  Neither  Agree
# The important interests/activities in your life...  Neither  Agree
# You know how much time you spend on each of the...  Neither  Agree
#
#                                                                5
# 0
# You often feel that your life is aimless, with ...  Strong Agree
# You never have trouble organizing the things yo...  Strong Agree
# Once you've started an activity, you persist at...  Strong Agree
# Sometimes you feel that the things you have to ...  Strong Agree
# You will plan your activities from day to day.      Strong Agree
# You tend to leave things to the last minute?        Strong Agree
# You tend to change rather aimlessly from one ac...  Strong Agree
# You give up the things that you planning to do ...  Strong Agree
# You think you do enough with your time.             Strong Agree
# You are easy to get bored with your day-today a...  Strong Agree
# The important interests/activities in your life...  Strong Agree
# You know how much time you spend on each of the...  Strong Agree

# %% [markdown]
# # TEST DATA

# %%
feat = read_ord('preprocessed test data ordinal.csv')
feat_nom = read_nom('preprocessed test data nominal.csv')
feat.update(feat_nom)

# %% [markdown]
# ## TEST 1

# %%
for f in feat.keys():
    print('name:',f)
    print('type:',feat[f].feat_type)
    print('num_cat:',feat[f].num_cat)
    print()
    for cat in feat[f].categories.keys():
        print('    index:',feat[f].categories[cat].index)
        print('    name:',feat[f].categories[cat].name)
        print()
    print()
# Out:
# name: You often feel that your life is aimless, with no definite purpose
# type: ordinal
# num_cat: 5
#
#     index: 0
#     name: Strong Disagree
#
#     index: 1
#     name: Disagree
#
#     index: 2
#     name: Neither
#
#     index: 3
#     name: Agree
#
#     index: 4
#     name: Strong Agree
#
#
# name: You never have trouble organizing the things you have to do?
# type: ordinal
# num_cat: 5
#
#     index: 0
#     name: Strong Disagree
#
#     index: 1
#     name: Disagree
#
#     index: 2
#     name: Neither
#
#     index: 3
#     name: Agree
#
#     index: 4
#     name: Strong Agree
#
#
# name: Once you've started an activity, you persist at it until you've completed it
# type: ordinal
# num_cat: 5
#
#     index: 0
#     name: Strong Disagree
#
#     index: 1
#     name: Disagree
#
#     index: 2
#     name: Neither
#
#     index: 3
#     name: Agree
#
#     index: 4
#     name: Strong Agree
#
#
# name: Sometimes you feel that the things you have to do during the day just don't seem to matter
# type: ordinal
# num_cat: 5
#
#     index: 0
#     name: Strong Disagree
#
#     index: 1
#     name: Disagree
#
#     index: 2
#     name: Neither
#
#     index: 3
#     name: Agree
#
#     index: 4
#     name: Strong Agree
#
#
# name: You will plan your activities from day to day.
# type: ordinal
# num_cat: 5
#
#     index: 0
#     name: Strong Disagree
#
#     index: 1
#     name: Disagree
#
#     index: 2
#     name: Neither
#
#     index: 3
#     name: Agree
#
#     index: 4
#     name: Strong Agree
#
#
# name: You tend to leave things to the last minute?
# type: ordinal
# num_cat: 5
#
#     index: 0
#     name: Strong Disagree
#
#     index: 1
#     name: Disagree
#
#     index: 2
#     name: Neither
#
#     index: 3
#     name: Agree
#
#     index: 4
#     name: Strong Agree
#
#
# name: You tend to change rather aimlessly from one activity to another during the day.
# type: ordinal
# num_cat: 5
#
#     index: 0
#     name: Strong Disagree
#
#     index: 1
#     name: Disagree
#
#     index: 2
#     name: Neither
#
#     index: 3
#     name: Agree
#
#     index: 4
#     name: Strong Agree
#
#
# name: You give up the things that you planning to do just because your friend says no.
# type: ordinal
# num_cat: 5
#
#     index: 0
#     name: Strong Disagree
#
#     index: 1
#     name: Disagree
#
#     index: 2
#     name: Neither
#
#     index: 3
#     name: Agree
#
#     index: 4
#     name: Strong Agree
#
#
# name: You think you do enough with your time.
# type: ordinal
# num_cat: 5
#
#     index: 0
#     name: Strong Disagree
#
#     index: 1
#     name: Disagree
#
#     index: 2
#     name: Neither
#
#     index: 3
#     name: Agree
#
#     index: 4
#     name: Strong Agree
#
#
# name: You are easy to get bored with your day-today activities.
# type: ordinal
# num_cat: 5
#
#     index: 0
#     name: Strong Disagree
#
#     index: 1
#     name: Disagree
#
#     index: 2
#     name: Neither
#
#     index: 3
#     name: Agree
#
#     index: 4
#     name: Strong Agree
#
#
# name: The important interests/activities in your life tend to change frequently.
# type: ordinal
# num_cat: 5
#
#     index: 0
#     name: Strong Disagree
#
#     index: 1
#     name: Disagree
#
#     index: 2
#     name: Neither
#
#     index: 3
#     name: Agree
#
#     index: 4
#     name: Strong Agree
#
#
# name: You know how much time you spend on each of the homework I do.
# type: ordinal
# num_cat: 5
#
#     index: 0
#     name: Strong Disagree
#
#     index: 1
#     name: Disagree
#
#     index: 2
#     name: Neither
#
#     index: 3
#     name: Agree
#
#     index: 4
#     name: Strong Agree
#
#
# name: Age
# type: nominal
# num_cat: 6
#
#     index: 0
#     name: <18
#
#     index: 1
#     name: 18-20
#
#     index: 2
#     name: 21-25
#
#     index: 3
#     name: 26-30
#
#     index: 4
#     name: 31-35
#
#     index: 5
#     name: >36
#
#
# name: Gender
# type: nominal
# num_cat: 2
#
#     index: 0
#     name: M
#
#     index: 1
#     name: F
#
#
# name: Nationality
# type: nominal
# num_cat: 26
#
#     index: 0
#     name: Korea
#
#     index: 1
#     name: China
#
#     index: 2
#     name: Kenya
#
#     index: 3
#     name: Vietnam
#
#     index: 4
#     name: India
#
#     index: 5
#     name: Saudi Arabia
#
#     index: 6
#     name: Tanzania
#
#     index: 7
#     name: Oman
#
#     index: 8
#     name: Jordan
#
#     index: 9
#     name: Zimbabwe
#
#     index: 10
#     name: Portugal
#
#     index: 11
#     name: Georgia
#
#     index: 12
#     name: Singapore
#
#     index: 13
#     name: Malaysia
#
#     index: 14
#     name: Qatar
#
#     index: 15
#     name: Turkey
#
#     index: 16
#     name: Kuwait
#
#     index: 17
#     name: OCEAN
#
#     index: 18
#     name: UK
#
#     index: 19
#     name: Pakistan
#
#     index: 20
#     name: Thailand
#
#     index: 21
#     name: Indonesia
#
#     index: 22
#     name: Trinidad and Tobago
#
#     index: 23
#     name: Colombia
#
#     index: 24
#     name: Gongo
#
#     index: 25
#     name: Ukraine
#
#
# name: Program
# type: nominal
# num_cat: 4
#
#     index: 0
#     name: PM
#
#     index: 1
#     name: IYO
#
#     index: 2
#     name: FC
#
#     index: 3
#     name: Language
#
#
# name: Course
# type: nominal
# num_cat: 7
#
#     index: 0
#     name: Social Sciences and Humanities
#
#     index: 1
#     name: Science and engineering
#
#     index: 2
#     name: Business
#
#     index: 3
#     name: Law/Legal studies
#
#     index: 4
#     name: Art and Design
#
#     index: 5
#     name: Computing
#
#     index: 6
#     name: Media and Communications
#
#
# name: English
# type: nominal
# num_cat: 5
#
#     index: 0
#     name: <40%
#
#     index: 1
#     name: 40%~49%
#
#     index: 2
#     name: 50%~59%
#
#     index: 3
#     name: 60%~70%
#
#     index: 4
#     name: >70%
#
#
# name: Academic
# type: nominal
# num_cat: 5
#
#     index: 0
#     name: <40%
#
#     index: 1
#     name: 40%~49%
#
#     index: 2
#     name: 50%~59%
#
#     index: 3
#     name: 60%~70%
#
#     index: 4
#     name: >70%
#
#
# name: Attendance
# type: nominal
# num_cat: 5
#
#     index: 0
#     name: S0
#
#     index: 1
#     name: S1
#
#     index: 2
#     name: S2
#
#     index: 3
#     name: S3
#
#     index: 4
#     name: S4

# %% [markdown]
# # Verdict: Working

# %% [markdown]
# # READ POPULATION

# %%
 df = pd.read_csv('International students Time management data.csv', index_col=0)

# %%
df
# Out:
#           Age Gender          Nationality Program  \
# Number
# 1       31-35      M                Korea      PM
# 2       26-30      M                China      PM
# 3       26-30      M                Kenya      PM
# 4       21-25      M              Vietnam      PM
# 5       21-25      M                China      PM
# 6       21-25      M                China      PM
# 7       21-25      M                China      PM
# 8       21-25      M                China      PM
# 9       21-25      M                China      PM
# 10      21-25      M                China      PM
# 11      21-25      M                China      PM
# 12      18-20      M                China     IYO
# 13      18-20      M                China     IYO
# 14      18-20      M                India     IYO
# 15      18-20      M         Saudi Arabia      FC
# 16      18-20      M                China      FC
# 17        >36      M                Korea      PM
# 18        <18      M         Saudi Arabia      FC
# 19        <18      M             Tanzania      FC
# 20        <18      M                China      FC
# 21      18-20      M                 Oman      FC
# 22      18-20      M               Jordan      FC
# 23      18-20      M             Zimbabwe      FC
# 24      18-20      M                 Oman      FC
# 25      18-20      M             Portugal      FC
# 26      18-20      M                 Oman      FC
# 27      18-20      M                China      FC
# 28        <18      M              Georgia     IYO
# 29      18-20      M                China     IYO
# 30      18-20      M                India     IYO
# ...       ...    ...                  ...     ...
# 96      21-25      F                China      PM
# 97      21-25      F                Korea      PM
# 98      21-25      F                China      PM
# 99      21-25      F                China      PM
# 100     21-25      F                China      PM
# 101     21-25      F                China      PM
# 102     21-25      F  Trinidad and Tobago      PM
# 103     21-25      F                China      PM
# 104     21-25      F                China      PM
# 105     21-25      F                China      PM
# 106     21-25      F                China      PM
# 107     21-25      F                China      PM
# 108     21-25      F                China      PM
# 109     21-25      F                China      PM
# 110     21-25      F                China      PM
# 111     21-25      F                China      PM
# 112     31-35      F                Korea      PM
# 113       >36      F             Colombia     IYO
# 114     21-25      F                China      PM
# 115     18-20      F                China      PM
# 116     21-25      M                China      PM
# 117     21-25      M                China      PM
# 118     21-25      M                China      PM
# 119     21-25      F                China      PM
# 120     21-25      M                China      PM
# 121     21-25      M                China      PM
# 122     31-35      F                China      PM
# 123     26-30      M                Gongo      PM
# 124     21-25      F              Ukraine      PM
# 125     26-30      F                Korea      PM
#
#                                 Course  English Academic Attendance  \
# Number
# 1       Social Sciences and Humanities  60%~70%      NaN         S0
# 2              Science and engineering  60%~70%  50%~59%         S3
# 3                             Business  60%~70%      NaN         S0
# 4                    Law/Legal studies  60%~70%  60%~70%         S0
# 5                             Business  60%~70%  50%~59%         S1
# 6                    Law/Legal studies  60%~70%  60%~70%         S0
# 7                       Art and Design  60%~70%  60%~70%         S0
# 8                             Business  60%~70%      NaN         S0
# 9                            Computing  60%~70%  40%~49%         S0
# 10                           Computing  60%~70%     >70%         S0
# 11                            Business  60%~70%     >70%         S1
# 12                            Business  60%~70%  50%~59%         S1
# 13                            Business  60%~70%  60%~70%         S3
# 14                            Business  60%~70%  60%~70%         S2
# 15                            Business     >70%  60%~70%         S1
# 16                            Business     >70%     >70%         S1
# 17                   Law/Legal studies     >70%      NaN         S0
# 18                           Computing     >70%  60%~70%         S0
# 19                            Business  60%~70%  60%~70%         S0
# 20                            Business  60%~70%  60%~70%         S0
# 21      Social Sciences and Humanities  60%~70%     >70%         S4
# 22            Media and Communications  60%~70%  60%~70%         S0
# 23                      Art and Design  60%~70%     >70%         S0
# 24      Social Sciences and Humanities  60%~70%      NaN         S0
# 25                            Business  60%~70%  50%~59%         S3
# 26                   Law/Legal studies  60%~70%      NaN         S0
# 27                            Business  60%~70%  60%~70%         S2
# 28                            Business  60%~70%  50%~59%         S3
# 29                            Business  60%~70%  50%~59%         S1
# 30                            Business  60%~70%  60%~70%         S2
# ...                                ...      ...      ...        ...
# 96                            Business  50%~59%  50%~59%         S1
# 97                            Business      NaN      NaN        NaN
# 98                            Business  60%~70%  60%~70%         S0
# 99                            Business  50%~59%  50%~59%         S0
# 100                           Business      NaN      NaN        NaN
# 101                           Business     >70%  60%~70%         S4
# 102     Social Sciences and Humanities     >70%     >70%         S2
# 103                           Business  50%~59%  50%~59%         S1
# 104                           Business  50%~59%  60%~70%         S0
# 105                           Business  50%~59%  50%~59%         S0
# 106                           Business  60%~70%  60%~70%         S0
# 107                           Business  60%~70%  60%~70%         S0
# 108                           Business  60%~70%  50%~59%         S0
# 109                           Business  40%~49%      NaN         S0
# 110                           Business  60%~70%  60%~70%         S0
# 111                  Law/Legal studies      NaN      NaN        NaN
# 112     Social Sciences and Humanities      NaN      NaN        NaN
# 113     Social Sciences and Humanities  40%~49%  40%~49%         S3
# 114                           Business  50%~59%  60%~70%         S0
# 115                           Business  50%~59%  50%~59%         S0
# 116                           Business  60%~70%  50%~59%         S1
# 117                           Business  60%~70%  60%~70%         S0
# 118                           Business  60%~70%  50%~59%         S0
# 119                           Business  50%~59%  60%~70%         S0
# 120                           Business  50%~59%  40%~49%         S3
# 121                           Business  60%~70%  50%~59%         S1
# 122                           Business  50%~59%  50%~59%         S1
# 123                           Business     >70%  60%~70%         S0
# 124                           Business  60%~70%  60%~70%         S1
# 125                           Business  60%~70%     >70%         S0
#
#        You often feel that your life is aimless, with no definite purpose  \
# Number
# 1                                                Disagree
# 2                                            Strong Agree
# 3                                                Disagree
# 4                                                Disagree
# 5                                                 Neither
# 6                                                   Agree
# 7                                                Disagree
# 8                                                   Agree
# 9                                                Disagree
# 10                                        Strong Disagree
# 11                                        Strong Disagree
# 12                                                Neither
# 13                                               Disagree
# 14                                                  Agree
# 15                                               Disagree
# 16                                           Strong Agree
# 17                                                Neither
# 18                                               Disagree
# 19                                               Disagree
# 20                                                  Agree
# 21                                           Strong Agree
# 22                                               Disagree
# 23                                               Disagree
# 24                                               Disagree
# 25                                                  Agree
# 26                                                    NaN
# 27                                                Neither
# 28                                           Strong Agree
# 29                                        Strong Disagree
# 30                                                Neither
# ...                                                   ...
# 96                                               Disagree
# 97                                               Disagree
# 98                                               Disagree
# 99                                                  Agree
# 100                                              Disagree
# 101                                       Strong Disagree
# 102                                               Neither
# 103                                              Disagree
# 104                                              Disagree
# 105                                              Disagree
# 106                                              Disagree
# 107                                              Disagree
# 108                                               Neither
# 109                                                 Agree
# 110                                               Neither
# 111                                       Strong Disagree
# 112                                          Strong Agree
# 113                                               Neither
# 114                                              Disagree
# 115                                               Neither
# 116                                       Strong Disagree
# 117                                              Disagree
# 118                                              Disagree
# 119                                              Disagree
# 120                                               Neither
# 121                                              Disagree
# 122                                                 Agree
# 123                                       Strong Disagree
# 124                                                 Agree
# 125                                              Disagree
#
#        You never have trouble organizing the things you have to do?  \
# Number
# 1                                                   Agree
# 2                                                   Agree
# 3                                            Strong Agree
# 4                                                Disagree
# 5                                                Disagree
# 6                                                 Neither
# 7                                                   Agree
# 8                                                 Neither
# 9                                                Disagree
# 10                                                  Agree
# 11                                                Neither
# 12                                               Disagree
# 13                                                Neither
# 14                                                  Agree
# 15                                                  Agree
# 16                                           Strong Agree
# 17                                               Disagree
# 18                                               Disagree
# 19                                               Disagree
# 20                                                  Agree
# 21                                                  Agree
# 22                                                Neither
# 23                                               Disagree
# 24                                               Disagree
# 25                                           Strong Agree
# 26                                                Neither
# 27                                                  Agree
# 28                                                  Agree
# 29                                                  Agree
# 30                                                Neither
# ...                                                   ...
# 96                                                  Agree
# 97                                                  Agree
# 98                                        Strong Disagree
# 99                                           Strong Agree
# 100                                                 Agree
# 101                                          Strong Agree
# 102                                              Disagree
# 103                                               Neither
# 104                                               Neither
# 105                                       Strong Disagree
# 106                                                 Agree
# 107                                               Neither
# 108                                              Disagree
# 109                                              Disagree
# 110                                              Disagree
# 111                                              Disagree
# 112                                              Disagree
# 113                                               Neither
# 114                                              Disagree
# 115                                                 Agree
# 116                                               Neither
# 117                                                 Agree
# 118                                              Disagree
# 119                                              Disagree
# 120                                               Neither
# 121                                              Disagree
# 122                                              Disagree
# 123                                               Neither
# 124                                              Disagree
# 125                                       Strong Disagree
#
#        Once you've started an activity, you persist at it until you've completed it  \
# Number
# 1                                            Strong Agree
# 2                                                 Neither
# 3                                                   Agree
# 4                                                   Agree
# 5                                                 Neither
# 6                                                   Agree
# 7                                                   Agree
# 8                                                 Neither
# 9                                         Strong Disagree
# 10                                                  Agree
# 11                                                Neither
# 12                                                Neither
# 13                                                Neither
# 14                                                  Agree
# 15                                               Disagree
# 16                                                  Agree
# 17                                                  Agree
# 18                                                Neither
# 19                                                  Agree
# 20                                           Strong Agree
# 21                                           Strong Agree
# 22                                                Neither
# 23                                               Disagree
# 24                                                Neither
# 25                                                Neither
# 26                                                  Agree
# 27                                                Neither
# 28                                               Disagree
# 29                                                  Agree
# 30                                                Neither
# ...                                                   ...
# 96                                                  Agree
# 97                                           Strong Agree
# 98                                           Strong Agree
# 99                                                  Agree
# 100                                                 Agree
# 101                                          Strong Agree
# 102                                               Neither
# 103                                                   NaN
# 104                                                 Agree
# 105                                              Disagree
# 106                                              Disagree
# 107                                                 Agree
# 108                                                 Agree
# 109                                                 Agree
# 110                                                 Agree
# 111                                              Disagree
# 112                                               Neither
# 113                                               Neither
# 114                                                 Agree
# 115                                          Strong Agree
# 116                                          Strong Agree
# 117                                                 Agree
# 118                                                 Agree
# 119                                                 Agree
# 120                                              Disagree
# 121                                                 Agree
# 122                                               Neither
# 123                                               Neither
# 124                                              Disagree
# 125                                                 Agree
#
#        Sometimes you feel that the things you have to do during the day just don't seem to matter  \
# Number
# 1                                                 Neither
# 2                                                Disagree
# 3                                                Disagree
# 4                                                   Agree
# 5                                                 Neither
# 6                                            Strong Agree
# 7                                                 Neither
# 8                                                   Agree
# 9                                                   Agree
# 10                                                Neither
# 11                                                Neither
# 12                                                Neither
# 13                                                Neither
# 14                                                  Agree
# 15                                                  Agree
# 16                                                Neither
# 17                                                  Agree
# 18                                                  Agree
# 19                                               Disagree
# 20                                                  Agree
# 21                                                Neither
# 22                                                Neither
# 23                                                  Agree
# 24                                               Disagree
# 25                                                  Agree
# 26                                               Disagree
# 27                                                  Agree
# 28                                        Strong Disagree
# 29                                                Neither
# 30                                                Neither
# ...                                                   ...
# 96                                                    NaN
# 97                                                Neither
# 98                                               Disagree
# 99                                                Neither
# 100                                                   NaN
# 101                                       Strong Disagree
# 102                                                 Agree
# 103                                               Neither
# 104                                               Neither
# 105                                                   NaN
# 106                                               Neither
# 107                                                 Agree
# 108                                               Neither
# 109                                              Disagree
# 110                                                 Agree
# 111                                               Neither
# 112                                                 Agree
# 113                                               Neither
# 114                                              Disagree
# 115                                               Neither
# 116                                                 Agree
# 117                                               Neither
# 118                                                 Agree
# 119                                               Neither
# 120                                                 Agree
# 121                                               Neither
# 122                                                 Agree
# 123                                               Neither
# 124                                          Strong Agree
# 125                                                 Agree
#
#        You will plan your activities from day to day.  \
# Number
# 1                                               Agree
# 2                                               Agree
# 3                                               Agree
# 4                                            Disagree
# 5                                            Disagree
# 6                                            Disagree
# 7                                               Agree
# 8                                               Agree
# 9                                            Disagree
# 10                                           Disagree
# 11                                            Neither
# 12                                       Strong Agree
# 13                                           Disagree
# 14                                            Neither
# 15                                    Strong Disagree
# 16                                       Strong Agree
# 17                                            Neither
# 18                                            Neither
# 19                                       Strong Agree
# 20                                       Strong Agree
# 21                                           Disagree
# 22                                              Agree
# 23                                           Disagree
# 24                                            Neither
# 25                                            Neither
# 26                                           Disagree
# 27                                           Disagree
# 28                                    Strong Disagree
# 29                                              Agree
# 30                                            Neither
# ...                                               ...
# 96                                              Agree
# 97                                       Strong Agree
# 98                                              Agree
# 99                                              Agree
# 100                                             Agree
# 101                                      Strong Agree
# 102                                             Agree
# 103                                           Neither
# 104                                             Agree
# 105                                             Agree
# 106                                             Agree
# 107                                             Agree
# 108                                             Agree
# 109                                             Agree
# 110                                             Agree
# 111                                             Agree
# 112                                           Neither
# 113                                           Neither
# 114                                           Neither
# 115                                             Agree
# 116                                           Neither
# 117                                             Agree
# 118                                             Agree
# 119                                             Agree
# 120                                           Neither
# 121                                          Disagree
# 122                                           Neither
# 123                                           Neither
# 124                                          Disagree
# 125                                             Agree
#
#        You tend to leave things to the last minute?  \
# Number
# 1                                           Neither
# 2                                           Neither
# 3                                             Agree
# 4                                             Agree
# 5                                           Neither
# 6                                          Disagree
# 7                                           Neither
# 8                                           Neither
# 9                                             Agree
# 10                                  Strong Disagree
# 11                                          Neither
# 12                                            Agree
# 13                                         Disagree
# 14                                          Neither
# 15                                         Disagree
# 16                                     Strong Agree
# 17                                         Disagree
# 18                                  Strong Disagree
# 19                                         Disagree
# 20                                     Strong Agree
# 21                                          Neither
# 22                                            Agree
# 23                                            Agree
# 24                                         Disagree
# 25                                          Neither
# 26                                          Neither
# 27                                            Agree
# 28                                  Strong Disagree
# 29                                            Agree
# 30                                         Disagree
# ...                                             ...
# 96                                              NaN
# 97                                  Strong Disagree
# 98                                         Disagree
# 99                                         Disagree
# 100                                        Disagree
# 101                                        Disagree
# 102                                        Disagree
# 103                                         Neither
# 104                                 Strong Disagree
# 105                                        Disagree
# 106                                           Agree
# 107                                        Disagree
# 108                                         Neither
# 109                                           Agree
# 110                                           Agree
# 111                                           Agree
# 112                                    Strong Agree
# 113                                         Neither
# 114                                        Disagree
# 115                                 Strong Disagree
# 116                                        Disagree
# 117                                         Neither
# 118                                           Agree
# 119                                           Agree
# 120                                           Agree
# 121                                        Disagree
# 122                                    Strong Agree
# 123                                         Neither
# 124                                           Agree
# 125                                 Strong Disagree
#
#        You tend to change rather aimlessly from one activity to another during the day.  \
# Number
# 1                                                Disagree
# 2                                                Disagree
# 3                                                Disagree
# 4                                                 Neither
# 5                                                 Neither
# 6                                            Strong Agree
# 7                                                 Neither
# 8                                                   Agree
# 9                                                   Agree
# 10                                        Strong Disagree
# 11                                                Neither
# 12                                                Neither
# 13                                               Disagree
# 14                                                  Agree
# 15                                           Strong Agree
# 16                                                  Agree
# 17                                               Disagree
# 18                                                Neither
# 19                                               Disagree
# 20                                                  Agree
# 21                                                  Agree
# 22                                                  Agree
# 23                                                  Agree
# 24                                           Strong Agree
# 25                                               Disagree
# 26                                                Neither
# 27                                                Neither
# 28                                               Disagree
# 29                                                  Agree
# 30                                                Neither
# ...                                                   ...
# 96                                                Neither
# 97                                                  Agree
# 98                                               Disagree
# 99                                           Strong Agree
# 100                                               Neither
# 101                                       Strong Disagree
# 102                                               Neither
# 103                                               Neither
# 104                                                 Agree
# 105                                                 Agree
# 106                                              Disagree
# 107                                              Disagree
# 108                                                 Agree
# 109                                                 Agree
# 110                                               Neither
# 111                                               Neither
# 112                                                 Agree
# 113                                               Neither
# 114                                              Disagree
# 115                                              Disagree
# 116                                               Neither
# 117                                               Neither
# 118                                               Neither
# 119                                                 Agree
# 120                                              Disagree
# 121                                               Neither
# 122                                                 Agree
# 123                                               Neither
# 124                                                 Agree
# 125                                              Disagree
#
#        You give up the things that you planning to do just because your friend says no.  \
# Number
# 1                                         Strong Disagree
# 2                                         Strong Disagree
# 3                                         Strong Disagree
# 4                                                 Neither
# 5                                                 Neither
# 6                                                   Agree
# 7                                         Strong Disagree
# 8                                                 Neither
# 9                                                Disagree
# 10                                        Strong Disagree
# 11                                                Neither
# 12                                               Disagree
# 13                                               Disagree
# 14                                                Neither
# 15                                        Strong Disagree
# 16                                           Strong Agree
# 17                                               Disagree
# 18                                                  Agree
# 19                                                  Agree
# 20                                           Strong Agree
# 21                                               Disagree
# 22                                               Disagree
# 23                                        Strong Disagree
# 24                                        Strong Disagree
# 25                                           Strong Agree
# 26                                        Strong Disagree
# 27                                                Neither
# 28                                        Strong Disagree
# 29                                                  Agree
# 30                                                Neither
# ...                                                   ...
# 96                                               Disagree
# 97                                               Disagree
# 98                                        Strong Disagree
# 99                                               Disagree
# 100                                              Disagree
# 101                                              Disagree
# 102                                       Strong Disagree
# 103                                       Strong Disagree
# 104                                               Neither
# 105                                              Disagree
# 106                                              Disagree
# 107                                              Disagree
# 108                                               Neither
# 109                                              Disagree
# 110                                               Neither
# 111                                              Disagree
# 112                                       Strong Disagree
# 113                                               Neither
# 114                                       Strong Disagree
# 115                                       Strong Disagree
# 116                                              Disagree
# 117                                              Disagree
# 118                                       Strong Disagree
# 119                                              Disagree
# 120                                               Neither
# 121                                              Disagree
# 122                                                 Agree
# 123                                       Strong Disagree
# 124                                       Strong Disagree
# 125                                       Strong Disagree
#
#        You think you do enough with your time.  \
# Number
# 1                                 Strong Agree
# 2                                      Neither
# 3                                     Disagree
# 4                                      Neither
# 5                                      Neither
# 6                                 Strong Agree
# 7                                     Disagree
# ...
# 27                             Strong Disagree
# 28                                       Agree
# 29                                       Agree
# 30                                     Neither
# ...                                        ...
# 96                                    Disagree
# 97                                     Neither
# 98                                       Agree
# 99                                       Agree
# 100                                    Neither
# 101                               Strong Agree
# 102                               Strong Agree
# 103                                    Neither
# 104                                      Agree
# 105                                      Agree
# 106                                    Neither
# 107                                      Agree
# 108                                   Disagree
# 109                                    Neither
# 110                                   Disagree
# 111                                   Disagree
# 112                                   Disagree
# 113                                    Neither
# 114                                   Disagree
# 115                                    Neither
# 116                                   Disagree
# 117                                    Neither
# 118                                      Agree
# 119                                    Neither
# 120                                    Neither
# 121                                   Disagree
# 122                                   Disagree
# 123                                   Disagree
# 124                                   Disagree
# 125                                      Agree
#
#        You are easy to get bored with your day-today activities.  \
# Number
# 1                                                 Neither
# 2                                                   Agree
# 3                                            Strong Agree
# 4                                                 Neither
# 5                                                Disagree
# 6                                            Strong Agree
# 7                                         Strong Disagree
# 8                                                   Agree
# 9                                                Disagree
# 10                                                  Agree
# 11                                                Neither
# 12                                                  Agree
# 13                                               Disagree
# 14                                                Neither
# 15                                                Neither
# 16                                                Neither
# 17                                               Disagree
# 18                                           Strong Agree
# 19                                               Disagree
# 20                                                  Agree
# 21                                               Disagree
# 22                                                  Agree
# 23                                                  Agree
# 24                                               Disagree
# 25                                                Neither
# 26                                                Neither
# 27                                           Strong Agree
# 28                                                Neither
# 29                                                  Agree
# 30                                                  Agree
# ...                                                   ...
# 96                                               Disagree
# 97                                               Disagree
# 98                                                  Agree
# 99                                                Neither
# 100                                              Disagree
# 101                                       Strong Disagree
# 102                                               Neither
# 103                                               Neither
# 104                                              Disagree
# 105                                              Disagree
# 106                                               Neither
# 107                                                 Agree
# 108                                                 Agree
# 109                                       Strong Disagree
# 110                                                 Agree
# 111                                              Disagree
# 112                                              Disagree
# 113                                               Neither
# 114                                                 Agree
# 115                                               Neither
# 116                                               Neither
# 117                                              Disagree
# 118                                                 Agree
# 119                                              Disagree
# 120                                       Strong Disagree
# 121                                                 Agree
# 122                                                 Agree
# 123                                          Strong Agree
# 124                                          Strong Agree
# 125                                               Neither
#
#        The important interests/activities in your life tend to change frequently.  \
# Number
# 1                                                Disagree
# 2                                                 Neither
# 3                                            Strong Agree
# 4                                                Disagree
# 5                                                 Neither
# 6                                         Strong Disagree
# 7                                         Strong Disagree
# 8                                                   Agree
# 9                                                Disagree
# 10                                        Strong Disagree
# 11                                                Neither
# 12                                                Neither
# 13                                                  Agree
# 14                                                  Agree
# 15                                                  Agree
# 16                                                  Agree
# 17                                               Disagree
# 18                                                Neither
# 19                                                  Agree
# 20                                                  Agree
# 21                                                Neither
# 22                                                  Agree
# 23                                                  Agree
# 24                                               Disagree
# 25                                           Strong Agree
# 26                                                Neither
# 27                                                Neither
# 28                                           Strong Agree
# 29                                                  Agree
# 30                                                Neither
# ...                                                   ...
# 96                                        Strong Disagree
# 97                                               Disagree
# 98                                               Disagree
# 99                                                Neither
# 100                                              Disagree
# 101                                                 Agree
# 102                                                 Agree
# 103                                               Neither
# 104                                                 Agree
# 105                                                 Agree
# 106                                              Disagree
# 107                                               Neither
# 108                                                 Agree
# 109                                               Neither
# 110                                               Neither
# 111                                               Neither
# 112                                              Disagree
# 113                                               Neither
# 114                                              Disagree
# 115                                               Neither
# 116                                                 Agree
# 117                                                 Agree
# 118                                          Strong Agree
# 119                                               Neither
# 120                                              Disagree
# 121                                               Neither
# 122                                          Strong Agree
# 123                                              Disagree
# 124                                              Disagree
# 125                                              Disagree
#
#        You know how much time you spend on each of the homework I do.
# Number
# 1                                                   Agree
# 2                                                Disagree
# 3                                                Disagree
# 4                                                   Agree
# 5                                                   Agree
# 6                                            Strong Agree
# 7                                                 Neither
# 8                                                   Agree
# 9                                                Disagree
# 10                                        Strong Disagree
# 11                                                Neither
# 12                                                  Agree
# 13                                                  Agree
# 14                                                  Agree
# 15                                               Disagree
# 16                                                Neither
# 17                                                Neither
# 18                                                Neither
# 19                                                Neither
# 20                                                  Agree
# 21                                                Neither
# 22                                                  Agree
# 23                                               Disagree
# 24                                                  Agree
# 25                                               Disagree
# 26                                                  Agree
# 27                                        Strong Disagree
# 28                                        Strong Disagree
# 29                                                  Agree
# 30                                                Neither
# ...                                                   ...
# 96                                               Disagree
# 97                                                  Agree
# 98                                               Disagree
# 99                                                  Agree
# 100                                                 Agree
# 101                                          Strong Agree
# 102                                                 Agree
# 103                                               Neither
# 104                                               Neither
# 105                                              Disagree
# 106                                                 Agree
# 107                                                 Agree
# 108                                                 Agree
# 109                                                 Agree
# 110                                              Disagree
# 111                                              Disagree
# 112                                       Strong Disagree
# 113                                               Neither
# 114                                                 Agree
# 115                                                 Agree
# 116                                                 Agree
# 117                                               Neither
# 118                                          Strong Agree
# 119                                                 Agree
# 120                                               Neither
# 121                                                 Agree
# 122                                                 Agree
# 123                                               Neither
# 124                                              Disagree
# 125                                          Strong Agree
#
# [125 rows x 20 columns]

# %% [markdown]
# ## TEST 2

# %%
feat = probability(df,feat)

# %%
for f in feat.keys():
    print(f)
    print(feat[f].feat_type,feat[f].num_cat)
    for cat in feat[f].categories.keys():
        print(feat[f].categories[cat].index,feat[f].categories[cat].name,feat[f].categories[cat].prob)
    print()
# Out:
# You often feel that your life is aimless, with no definite purpose
# ordinal 5
# 0 Strong Disagree 0.13008130081300814
# 1 Disagree 0.3902439024390244
# 2 Neither 0.21951219512195122
# 3 Agree 0.18699186991869918
# 4 Strong Agree 0.07317073170731707
#
# You never have trouble organizing the things you have to do?
# ordinal 5
# 0 Strong Disagree 0.056
# 1 Disagree 0.32
# 2 Neither 0.288
# 3 Agree 0.28
# 4 Strong Agree 0.056
#
# Once you've started an activity, you persist at it until you've completed it
# ordinal 5
# 0 Strong Disagree 0.008264462809917356
# 1 Disagree 0.12396694214876033
# 2 Neither 0.2892561983471074
# 3 Agree 0.47107438016528924
# 4 Strong Agree 0.10743801652892562
#
# Sometimes you feel that the things you have to do during the day just don't seem to matter
# ordinal 5
# 0 Strong Disagree 0.0423728813559322
# 1 Disagree 0.17796610169491525
# 2 Neither 0.4067796610169492
# 3 Agree 0.3474576271186441
# 4 Strong Agree 0.025423728813559324
#
# You will plan your activities from day to day.
# ordinal 5
# 0 Strong Disagree 0.06451612903225806
# 1 Disagree 0.20967741935483872
# 2 Neither 0.27419354838709675
# 3 Agree 0.3629032258064516
# 4 Strong Agree 0.08870967741935484
#
# You tend to leave things to the last minute?
# ordinal 5
# 0 Strong Disagree 0.10569105691056911
# 1 Disagree 0.2926829268292683
# 2 Neither 0.2764227642276423
# 3 Agree 0.25203252032520324
# 4 Strong Agree 0.07317073170731707
#
# You tend to change rather aimlessly from one activity to another during the day.
# ordinal 5
# 0 Strong Disagree 0.02459016393442623
# 1 Disagree 0.2459016393442623
# 2 Neither 0.4016393442622951
# 3 Agree 0.26229508196721313
# 4 Strong Agree 0.06557377049180328
#
# You give up the things that you planning to do just because your friend says no.
# ordinal 5
# 0 Strong Disagree 0.312
# 1 Disagree 0.336
# 2 Neither 0.208
# 3 Agree 0.104
# 4 Strong Agree 0.04
#
# You think you do enough with your time.
# ordinal 5
# 0 Strong Disagree 0.04032258064516129
# 1 Disagree 0.2903225806451613
# 2 Neither 0.29838709677419356
# 3 Agree 0.3064516129032258
# 4 Strong Agree 0.06451612903225806
#
# You are easy to get bored with your day-today activities.
# ordinal 5
# 0 Strong Disagree 0.04
# 1 Disagree 0.224
# 2 Neither 0.312
# 3 Agree 0.288
# 4 Strong Agree 0.136
#
# The important interests/activities in your life tend to change frequently.
# ordinal 5
# 0 Strong Disagree 0.04878048780487805
# 1 Disagree 0.25203252032520324
# 2 Neither 0.24390243902439024
# 3 Agree 0.36585365853658536
# 4 Strong Agree 0.08943089430894309
#
# You know how much time you spend on each of the homework I do.
# ordinal 5
# 0 Strong Disagree 0.08064516129032258
# 1 Disagree 0.23387096774193547
# 2 Neither 0.2661290322580645
# 3 Agree 0.3548387096774194
# 4 Strong Agree 0.06451612903225806
#
# Age
# nominal 6
# 0 <18 0.048
# 1 18-20 0.288
# 2 21-25 0.496
# 3 26-30 0.096
# 4 31-35 0.04
# 5 >36 0.032
#
# Gender
# nominal 2
# 0 M 0.496
# 1 F 0.504
#
# Nationality
# nominal 26
# 0 Korea 0.048
# 1 China 0.616
# 2 Kenya 0.008
# 3 Vietnam 0.024
# 4 India 0.024
# 5 Saudi Arabia 0.048
# 6 Tanzania 0.016
# 7 Oman 0.04
# 8 Jordan 0.008
# 9 Zimbabwe 0.016
# 10 Portugal 0.008
# 11 Georgia 0.008
# 12 Singapore 0.008
# 13 Malaysia 0.008
# 14 Qatar 0.016
# 15 Turkey 0.016
# 16 Kuwait 0.016
# 17 OCEAN 0.008
# 18 UK 0.008
# 19 Pakistan 0.008
# 20 Thailand 0.008
# 21 Indonesia 0.008
# 22 Trinidad and Tobago 0.008
# 23 Colombia 0.008
# 24 Gongo 0.008
# 25 Ukraine 0.008
#
# Program
# nominal 4
# 0 PM 0.624
# 1 IYO 0.12
# 2 FC 0.248
# 3 Language 0.008
#
# Course
# nominal 7
# 0 Social Sciences and Humanities 0.088
# 1 Science and engineering 0.032
# 2 Business 0.64
# 3 Law/Legal studies 0.112
# 4 Art and Design 0.056
# 5 Computing 0.048
# 6 Media and Communications 0.024
#
# English
# nominal 5
# 0 <40% 0.008403361344537815
# 1 40%~49% 0.03361344537815126
# 2 50%~59% 0.31092436974789917
# 3 60%~70% 0.5210084033613446
# 4 >70% 0.12605042016806722
#
# Academic
# nominal 5
# 0 <40% 0.019417475728155338
# 1 40%~49% 0.0970873786407767
# 2 50%~59% 0.33980582524271846
# 3 60%~70% 0.4174757281553398
# 4 >70% 0.1262135922330097
#
# Attendance
# nominal 5
# 0 S0 0.5294117647058824
# 1 S1 0.25210084033613445
# 2 S2 0.1092436974789916
# 3 S3 0.08403361344537816
# 4 S4 0.025210084033613446

# %% [markdown]
# ## TEST 3

# %%
feat = entropy(feat)

# %%
for f in feat.keys():
    print(f)
    print(feat[f].feat_type,feat[f].num_cat)
    for cat in feat[f].categories.keys():
        print(feat[f].categories[cat].index,feat[f].categories[cat].name,feat[f].categories[cat].prob,feat[f].categories[cat].entropy)
    print()
# Out:
# You often feel that your life is aimless, with no definite purpose
# ordinal 5
# 0 Strong Disagree 0.13008130081300814 0.26531325309042425
# 1 Disagree 0.3902439024390244 0.3672130124739616
# 2 Neither 0.21951219512195122 0.33285676595884867
# 3 Agree 0.18699186991869918 0.3135274244487411
# 4 Strong Agree 0.07317073170731707 0.19133852034411206
#
# You never have trouble organizing the things you have to do?
# ordinal 5
# 0 Strong Disagree 0.056 0.1614146009418313
# 1 Disagree 0.32 0.36461897062027676
# 2 Neither 0.288 0.358500902067703
# 3 Agree 0.28 0.3564303892276085
# 4 Strong Agree 0.056 0.1614146009418313
#
# Once you've started an activity, you persist at it until you've completed it
# ordinal 5
# 0 Strong Disagree 0.008264462809917356 0.03963463260823753
# 1 Disagree 0.12396694214876033 0.2588107865075865
# 2 Neither 0.2892561983471074 0.3588056772211277
# 3 Agree 0.47107438016528924 0.3545961886978916
# 4 Strong Agree 0.10743801652892562 0.23967715244427815
#
# Sometimes you feel that the things you have to do during the day just don't seem to matter
# ordinal 5
# 0 Strong Disagree 0.0423728813559322 0.13395113186574426
# 1 Disagree 0.17796610169491525 0.30719835526768713
# 2 Neither 0.4067796610169492 0.3658916394133317
# 3 Agree 0.3474576271186441 0.3673018209170817
# 4 Strong Agree 0.025423728813559324 0.0933577712490904
#
# You will plan your activities from day to day.
# ordinal 5
# 0 Strong Disagree 0.06451612903225806 0.17682838864033554
# 1 Disagree 0.20967741935483872 0.3275549251384873
# 2 Neither 0.27419354838709675 0.35478480156146586
# 3 Agree 0.3629032258064516 0.3678456323593731
# 4 Strong Agree 0.08870967741935484 0.21488910661994623
#
# You tend to leave things to the last minute?
# ordinal 5
# 0 Strong Disagree 0.10569105691056911 0.23751264205562156
# 1 Disagree 0.2926829268292683 0.35960939031696804
# 2 Neither 0.2764227642276423 0.35543097760742043
# 3 Agree 0.25203252032520324 0.3473505014431334
# 4 Strong Agree 0.07317073170731707 0.19133852034411206
#
# You tend to change rather aimlessly from one activity to another during the day.
# ordinal 5
# 0 Strong Disagree 0.02459016393442623 0.09111660875570032
# 1 Disagree 0.2459016393442623 0.3449566384601069
# 2 Neither 0.4016393442622951 0.36637570970908906
# 3 Agree 0.26229508196721313 0.3510256109989587
# 4 Strong Agree 0.06557377049180328 0.17866095101989643
#
# You give up the things that you planning to do just because your friend says no.
# ordinal 5
# 0 Strong Disagree 0.312 0.3634026524458683
# 1 Disagree 0.336 0.3664564239903614
# 2 Neither 0.208 0.32660517745041034
# 3 Agree 0.104 0.23538989550343947
# 4 Strong Agree 0.04 0.128755032994728
#
# You think you do enough with your time.
# ordinal 5
# 0 Strong Disagree 0.04032258064516129 0.12946950214398936
# 1 Disagree 0.2903225806451613 0.35906011755936584
# 2 Neither 0.29838709677419356 0.3608585093512101
# 3 Agree 0.3064516129032258 0.3624389147047479
# 4 Strong Agree 0.06451612903225806 0.17682838864033554
#
# You are easy to get bored with your day-today activities.
# ordinal 5
# 0 Strong Disagree 0.04 0.128755032994728
# 1 Disagree 0.224 0.3351284668764698
# 2 Neither 0.312 0.3634026524458683
# 3 Agree 0.288 0.358500902067703
# 4 Strong Agree 0.136 0.27133365348146754
#
# The important interests/activities in your life tend to change frequently.
# ordinal 5
# 0 Strong Disagree 0.04878048780487805 0.14733779932411525
# 1 Disagree 0.25203252032520324 0.3473505014431334
# 2 Neither 0.24390243902439024 0.3441431643195761
# 3 Agree 0.36585365853658536 0.36787385326906014
# 4 Strong Agree 0.08943089430894309 0.21591203177491475
#
# You know how much time you spend on each of the homework I do.
# ordinal 5
# 0 Strong Disagree 0.08064516129032258 0.2030400381137896
# 1 Disagree 0.23387096774193547 0.3398111801043413
# 2 Neither 0.2661290322580645 0.35229469464977714
# 3 Agree 0.3548387096774194 0.36764552414692037
# 4 Strong Agree 0.06451612903225806 0.17682838864033554
#
# Age
# nominal 6
# 0 <18 0.048 0.1457546048675638
# 1 18-20 0.288 0.358500902067703
# 2 21-25 0.496 0.347784958719576
# 3 26-30 0.096 0.22496708040137287
# 4 31-35 0.04 0.128755032994728
# 5 >36 0.032 0.11014462003783713
#
# Gender
# nominal 2
# 0 M 0.496 0.347784958719576
# 1 F 0.504 0.34533022149902726
#
# Nationality
# nominal 26
# 0 Korea 0.048 0.1457546048675638
# 1 China 0.616 0.29845712231634824
# 2 Kenya 0.008 0.03862650989841841
# 3 Vietnam 0.024 0.08951283476722059
# 4 India 0.024 0.08951283476722059
# 5 Saudi Arabia 0.048 0.1457546048675638
# 6 Tanzania 0.016 0.0661626649078777
# 7 Oman 0.04 0.128755032994728
# 8 Jordan 0.008 0.03862650989841841
# 9 Zimbabwe 0.016 0.0661626649078777
# 10 Portugal 0.008 0.03862650989841841
# 11 Georgia 0.008 0.03862650989841841
# 12 Singapore 0.008 0.03862650989841841
# 13 Malaysia 0.008 0.03862650989841841
# 14 Qatar 0.016 0.0661626649078777
# 15 Turkey 0.016 0.0661626649078777
# 16 Kuwait 0.016 0.0661626649078777
# 17 OCEAN 0.008 0.03862650989841841
# 18 UK 0.008 0.03862650989841841
# 19 Pakistan 0.008 0.03862650989841841
# 20 Thailand 0.008 0.03862650989841841
# 21 Indonesia 0.008 0.03862650989841841
# 22 Trinidad and Tobago 0.008 0.03862650989841841
# 23 Colombia 0.008 0.03862650989841841
# 24 Gongo 0.008 0.03862650989841841
# 25 Ukraine 0.008 0.03862650989841841
#
# Program
# nominal 4
# 0 PM 0.624 0.29428146422233065
# 1 IYO 0.12 0.2544316243440109
# 2 FC 0.248 0.3457929801386544
# 3 Language 0.008 0.03862650989841841
#
# Course
# nominal 7
# 0 Social Sciences and Humanities 0.088 0.2138768248763459
# 1 Science and engineering 0.032 0.11014462003783713
# 2 Business 0.64 0.28562374568218846
# 3 Law/Legal studies 0.112 0.24519671766094878
# 4 Art and Design 0.056 0.1614146009418313
# 5 Computing 0.048 0.1457546048675638
# 6 Media and Communications 0.024 0.08951283476722059
#
# English
# nominal 5
# 0 <40% 0.008403361344537815 0.04016070162278596
# 1 40%~49% 0.03361344537815126 0.1140446767056013
# 2 50%~59% 0.31092436974789917 0.3632235838427755
# 3 60%~70% 0.5210084033613446 0.33969180420268186
# 4 >70% 0.12605042016806722 0.2610596586566369
#
# Academic
# nominal 5
# 0 <40% 0.019417475728155338 0.07653556908096486
# 1 40%~49% 0.0970873786407767 0.22642173740151358
# 2 50%~59% 0.33980582524271846 0.3667799265622114
# 3 60%~70% 0.4174757281553398 0.36467710212671023
# 4 >70% 0.1262135922330097 0.26123432232995425
#
# Attendance
# nominal 5
# 0 S0 0.5294117647058824 0.3366999353223512
# 1 S1 0.25210084033613445 0.34737633061748924
# 2 S2 0.1092436974789916 0.24188456944075548
# 3 S3 0.08403361344537816 0.2081124705981079
# 4 S4 0.025210084033613446 0.09278599675067445

# %% [markdown]
# ## TEST 4

# %%
feat = std_entropy(feat)
feat = feature_entropy(feat)
feat = reliability(feat)
total_rel = total_reliability(feat)
feat = weights(feat, total_rel)

# %%
for f in feat.keys():
    print('name:',f)
    print('type:',feat[f].feat_type)
    print('num_cat:',feat[f].num_cat)
    print('entropy:',feat[f].entropy)
    print('std_entropy:',feat[f].std_entropy)
    print('reliability:',feat[f].reliability)
    print()
    for cat in feat[f].categories.keys():
        print('    index:',feat[f].categories[cat].index)
        print('    name:',feat[f].categories[cat].name)
        print('    prob:',feat[f].categories[cat].prob)
        print('    entropy:',feat[f].categories[cat].entropy)
        print()
    print()
# Out:
# name: You often feel that your life is aimless, with no definite purpose
# type: ordinal
# num_cat: 5
# entropy: 1.4702489763160878
# std_entropy: 1.6094379124341003
# reliability: 0.9135170514856927
#
#     index: 0
#     name: Strong Disagree
#     prob: 0.13008130081300814
#     entropy: 0.26531325309042425
#
#     index: 1
#     name: Disagree
#     prob: 0.3902439024390244
#     entropy: 0.3672130124739616
#
#     index: 2
#     name: Neither
#     prob: 0.21951219512195122
#     entropy: 0.33285676595884867
#
#     index: 3
#     name: Agree
#     prob: 0.18699186991869918
#     entropy: 0.3135274244487411
#
#     index: 4
#     name: Strong Agree
#     prob: 0.07317073170731707
#     entropy: 0.19133852034411206
#
#
# name: You never have trouble organizing the things you have to do?
# type: ordinal
# num_cat: 5
# entropy: 1.402379463799251
# std_entropy: 1.6094379124341003
# reliability: 0.8713473523674512
#
#     index: 0
#     name: Strong Disagree
#     prob: 0.056
#     entropy: 0.1614146009418313
#
#     index: 1
#     name: Disagree
#     prob: 0.32
#     entropy: 0.36461897062027676
#
#     index: 2
#     name: Neither
#     prob: 0.288
#     entropy: 0.358500902067703
#
#     index: 3
#     name: Agree
#     prob: 0.28
#     entropy: 0.3564303892276085
#
#     index: 4
#     name: Strong Agree
#     prob: 0.056
#     entropy: 0.1614146009418313
#
#
# name: Once you've started an activity, you persist at it until you've completed it
# type: ordinal
# num_cat: 5
# entropy: 1.2515244374791217
# std_entropy: 1.6094379124341003
# reliability: 0.7776158544608451
#
#     index: 0
#     name: Strong Disagree
#     prob: 0.008264462809917356
#     entropy: 0.03963463260823753
#
#     index: 1
#     name: Disagree
#     prob: 0.12396694214876033
#     entropy: 0.2588107865075865
#
#     index: 2
#     name: Neither
#     prob: 0.2892561983471074
#     entropy: 0.3588056772211277
#
#     index: 3
#     name: Agree
#     prob: 0.47107438016528924
#     entropy: 0.3545961886978916
#
#     index: 4
#     name: Strong Agree
#     prob: 0.10743801652892562
#     entropy: 0.23967715244427815
#
#
# name: Sometimes you feel that the things you have to do during the day just don't seem to matter
# type: ordinal
# num_cat: 5
# entropy: 1.267700718712935
# std_entropy: 1.6094379124341003
# reliability: 0.7876667431026744
#
#     index: 0
#     name: Strong Disagree
#     prob: 0.0423728813559322
#     entropy: 0.13395113186574426
#
#     index: 1
#     name: Disagree
#     prob: 0.17796610169491525
#     entropy: 0.30719835526768713
#
#     index: 2
#     name: Neither
#     prob: 0.4067796610169492
#     entropy: 0.3658916394133317
#
#     index: 3
#     name: Agree
#     prob: 0.3474576271186441
#     entropy: 0.3673018209170817
#
#     index: 4
#     name: Strong Agree
#     prob: 0.025423728813559324
#     entropy: 0.0933577712490904
#
#
# name: You will plan your activities from day to day.
# type: ordinal
# num_cat: 5
# entropy: 1.4419028543196082
# std_entropy: 1.6094379124341003
# reliability: 0.8959046156299912
#
#     index: 0
#     name: Strong Disagree
#     prob: 0.06451612903225806
#     entropy: 0.17682838864033554
#
#     index: 1
#     name: Disagree
#     prob: 0.20967741935483872
#     entropy: 0.3275549251384873
#
#     index: 2
#     name: Neither
#     prob: 0.27419354838709675
#     entropy: 0.35478480156146586
#
#     index: 3
#     name: Agree
#     prob: 0.3629032258064516
#     entropy: 0.3678456323593731
#
#     index: 4
#     name: Strong Agree
#     prob: 0.08870967741935484
#     entropy: 0.21488910661994623
#
#
# name: You tend to leave things to the last minute?
# type: ordinal
# num_cat: 5
# entropy: 1.4912420317672554
# std_entropy: 1.6094379124341003
# reliability: 0.9265607702206503
#
#     index: 0
#     name: Strong Disagree
#     prob: 0.10569105691056911
#     entropy: 0.23751264205562156
#
#     index: 1
#     name: Disagree
#     prob: 0.2926829268292683
#     entropy: 0.35960939031696804
#
#     index: 2
#     name: Neither
#     prob: 0.2764227642276423
#     entropy: 0.35543097760742043
#
#     index: 3
#     name: Agree
#     prob: 0.25203252032520324
#     entropy: 0.3473505014431334
#
#     index: 4
#     name: Strong Agree
#     prob: 0.07317073170731707
#     entropy: 0.19133852034411206
#
#
# name: You tend to change rather aimlessly from one activity to another during the day.
# type: ordinal
# num_cat: 5
# entropy: 1.3321355189437514
# std_entropy: 1.6094379124341003
# reliability: 0.8277023354874503
#
#     index: 0
#     name: Strong Disagree
#     prob: 0.02459016393442623
#     entropy: 0.09111660875570032
#
#     index: 1
#     name: Disagree
#     prob: 0.2459016393442623
#     entropy: 0.3449566384601069
#
#     index: 2
#     name: Neither
#     prob: 0.4016393442622951
#     entropy: 0.36637570970908906
#
#     index: 3
#     name: Agree
#     prob: 0.26229508196721313
#     entropy: 0.3510256109989587
#
#     index: 4
#     name: Strong Agree
#     prob: 0.06557377049180328
#     entropy: 0.17866095101989643
#
#
# name: You give up the things that you planning to do just because your friend says no.
# type: ordinal
# num_cat: 5
# entropy: 1.4206091823848075
# std_entropy: 1.6094379124341003
# reliability: 0.8826741133718481
#
#     index: 0
#     name: Strong Disagree
#     prob: 0.312
#     entropy: 0.3634026524458683
#
#     index: 1
#     name: Disagree
#     prob: 0.336
#     entropy: 0.3664564239903614
#
#     index: 2
#     name: Neither
#     prob: 0.208
#     entropy: 0.32660517745041034
#
#     index: 3
#     name: Agree
#     prob: 0.104
#     entropy: 0.23538989550343947
#
#     index: 4
#     name: Strong Agree
#     prob: 0.04
#     entropy: 0.128755032994728
#
#
# name: You think you do enough with your time.
# type: ordinal
# num_cat: 5
# entropy: 1.3886554323996487
# std_entropy: 1.6094379124341003
# reliability: 0.8628201322158853
#
#     index: 0
#     name: Strong Disagree
#     prob: 0.04032258064516129
#     entropy: 0.12946950214398936
#
#     index: 1
#     name: Disagree
#     prob: 0.2903225806451613
#     entropy: 0.35906011755936584
#
#     index: 2
#     name: Neither
#     prob: 0.29838709677419356
#     entropy: 0.3608585093512101
#
#     index: 3
#     name: Agree
#     prob: 0.3064516129032258
#     entropy: 0.3624389147047479
#
#     index: 4
#     name: Strong Agree
#     prob: 0.06451612903225806
#     entropy: 0.17682838864033554
#
#
# name: You are easy to get bored with your day-today activities.
# type: ordinal
# num_cat: 5
# entropy: 1.4571207078662365
# std_entropy: 1.6094379124341003
# reliability: 0.9053599996675233
#
#     index: 0
#     name: Strong Disagree
#     prob: 0.04
#     entropy: 0.128755032994728
#
#     index: 1
#     name: Disagree
#     prob: 0.224
#     entropy: 0.3351284668764698
#
#     index: 2
#     name: Neither
#     prob: 0.312
#     entropy: 0.3634026524458683
#
#     index: 3
#     name: Agree
#     prob: 0.288
#     entropy: 0.358500902067703
#
#     index: 4
#     name: Strong Agree
#     prob: 0.136
#     entropy: 0.27133365348146754
#
#
# name: The important interests/activities in your life tend to change frequently.
# type: ordinal
# num_cat: 5
# entropy: 1.4226173501307997
# std_entropy: 1.6094379124341003
# reliability: 0.8839218581468888
#
#     index: 0
#     name: Strong Disagree
#     prob: 0.04878048780487805
#     entropy: 0.14733779932411525
#
#     index: 1
#     name: Disagree
#     prob: 0.25203252032520324
#     entropy: 0.3473505014431334
#
#     index: 2
#     name: Neither
#     prob: 0.24390243902439024
#     entropy: 0.3441431643195761
#
#     index: 3
#     name: Agree
#     prob: 0.36585365853658536
#     entropy: 0.36787385326906014
#
#     index: 4
#     name: Strong Agree
#     prob: 0.08943089430894309
#     entropy: 0.21591203177491475
#
#
# name: You know how much time you spend on each of the homework I do.
# type: ordinal
# num_cat: 5
# entropy: 1.4396198256551638
# std_entropy: 1.6094379124341003
# reliability: 0.894486090164171
#
#     index: 0
#     name: Strong Disagree
#     prob: 0.08064516129032258
#     entropy: 0.2030400381137896
#
#     index: 1
#     name: Disagree
#     prob: 0.23387096774193547
#     entropy: 0.3398111801043413
#
#     index: 2
#     name: Neither
#     prob: 0.2661290322580645
#     entropy: 0.35229469464977714
#
#     index: 3
#     name: Agree
#     prob: 0.3548387096774194
#     entropy: 0.36764552414692037
#
#     index: 4
#     name: Strong Agree
#     prob: 0.06451612903225806
#     entropy: 0.17682838864033554
#
#
# name: Age
# type: nominal
# num_cat: 6
# entropy: 1.3159071990887807
# std_entropy: 1.791759469228055
# reliability: 0.7344217913667362
#
#     index: 0
#     name: <18
#     prob: 0.048
#     entropy: 0.1457546048675638
#
#     index: 1
#     name: 18-20
#     prob: 0.288
#     entropy: 0.358500902067703
#
#     index: 2
#     name: 21-25
#     prob: 0.496
#     entropy: 0.347784958719576
#
#     index: 3
#     name: 26-30
#     prob: 0.096
#     entropy: 0.22496708040137287
#
#     index: 4
#     name: 31-35
#     prob: 0.04
#     entropy: 0.128755032994728
#
#     index: 5
#     name: >36
#     prob: 0.032
#     entropy: 0.11014462003783713
#
#
# name: Gender
# type: nominal
# num_cat: 2
# entropy: 0.6931151802186033
# std_entropy: 0.6931471805599453
# reliability: 0.9999538332662392
#
#     index: 0
#     name: M
#     prob: 0.496
#     entropy: 0.347784958719576
#
#     index: 1
#     name: F
#     prob: 0.504
#     entropy: 0.34533022149902726
#
#
# name: Nationality
# type: nominal
# num_cat: 26
# entropy: 1.80795800759631
# std_entropy: 3.258096538021482
# reliability: 0.5549123503547915
#
#     index: 0
#     name: Korea
#     prob: 0.048
#     entropy: 0.1457546048675638
#
#     index: 1
#     name: China
#     prob: 0.616
#     entropy: 0.29845712231634824
#
#     index: 2
#     name: Kenya
#     prob: 0.008
#     entropy: 0.03862650989841841
#
#     index: 3
#     name: Vietnam
#     prob: 0.024
#     entropy: 0.08951283476722059
#
#     index: 4
#     name: India
#     prob: 0.024
#     entropy: 0.08951283476722059
#
#     index: 5
#     name: Saudi Arabia
#     prob: 0.048
#     entropy: 0.1457546048675638
#
#     index: 6
#     name: Tanzania
#     prob: 0.016
#     entropy: 0.0661626649078777
#
#     index: 7
#     name: Oman
#     prob: 0.04
#     entropy: 0.128755032994728
#
#     index: 8
#     name: Jordan
#     prob: 0.008
#     entropy: 0.03862650989841841
#
#     index: 9
#     name: Zimbabwe
#     prob: 0.016
#     entropy: 0.0661626649078777
#
#     index: 10
#     name: Portugal
#     prob: 0.008
#     entropy: 0.03862650989841841
#
#     index: 11
#     name: Georgia
#     prob: 0.008
#     entropy: 0.03862650989841841
#
#     index: 12
#     name: Singapore
#     prob: 0.008
#     entropy: 0.03862650989841841
#
#     index: 13
#     name: Malaysia
#     prob: 0.008
#     entropy: 0.03862650989841841
#
#     index: 14
#     name: Qatar
#     prob: 0.016
#     entropy: 0.0661626649078777
#
#     index: 15
#     name: Turkey
#     prob: 0.016
#     entropy: 0.0661626649078777
#
#     index: 16
#     name: Kuwait
#     prob: 0.016
#     entropy: 0.0661626649078777
#
#     index: 17
#     name: OCEAN
#     prob: 0.008
#     entropy: 0.03862650989841841
#
#     index: 18
#     name: UK
#     prob: 0.008
#     entropy: 0.03862650989841841
#
#     index: 19
#     name: Pakistan
#     prob: 0.008
#     entropy: 0.03862650989841841
#
#     index: 20
#     name: Thailand
#     prob: 0.008
#     entropy: 0.03862650989841841
#
#     index: 21
#     name: Indonesia
#     prob: 0.008
#     entropy: 0.03862650989841841
#
#     index: 22
#     name: Trinidad and Tobago
#     prob: 0.008
#     entropy: 0.03862650989841841
#
#     index: 23
#     name: Colombia
#     prob: 0.008
#     entropy: 0.03862650989841841
#
#     index: 24
#     name: Gongo
#     prob: 0.008
#     entropy: 0.03862650989841841
#
#     index: 25
#     name: Ukraine
#     prob: 0.008
#     entropy: 0.03862650989841841
#
#
# name: Program
# type: nominal
# num_cat: 4
# entropy: 0.9331325786034144
# std_entropy: 1.3862943611198906
# reliability: 0.6731128718215384
#
#     index: 0
#     name: PM
#     prob: 0.624
#     entropy: 0.29428146422233065
#
#     index: 1
#     name: IYO
#     prob: 0.12
#     entropy: 0.2544316243440109
#
#     index: 2
#     name: FC
#     prob: 0.248
#     entropy: 0.3457929801386544
#
#     index: 3
#     name: Language
#     prob: 0.008
#     entropy: 0.03862650989841841
#
#
# name: Course
# type: nominal
# num_cat: 7
# entropy: 1.2515239488339358
# std_entropy: 1.9459101490553132
# reliability: 0.6431560827418044
#
#     index: 0
#     name: Social Sciences and Humanities
#     prob: 0.088
#     entropy: 0.2138768248763459
#
#     index: 1
#     name: Science and engineering
#     prob: 0.032
#     entropy: 0.11014462003783713
#
#     index: 2
#     name: Business
#     prob: 0.64
#     entropy: 0.28562374568218846
#
#     index: 3
#     name: Law/Legal studies
#     prob: 0.112
#     entropy: 0.24519671766094878
#
#     index: 4
#     name: Art and Design
#     prob: 0.056
#     entropy: 0.1614146009418313
#
#     index: 5
#     name: Computing
#     prob: 0.048
#     entropy: 0.1457546048675638
#
#     index: 6
#     name: Media and Communications
#     prob: 0.024
#     entropy: 0.08951283476722059
#
#
# name: English
# type: nominal
# num_cat: 5
# entropy: 1.1181804250304814
# std_entropy: 1.6094379124341003
# reliability: 0.6947645612121531
#
#     index: 0
#     name: <40%
#     prob: 0.008403361344537815
#     entropy: 0.04016070162278596
#
#     index: 1
#     name: 40%~49%
#     prob: 0.03361344537815126
#     entropy: 0.1140446767056013
#
#     index: 2
#     name: 50%~59%
#     prob: 0.31092436974789917
#     entropy: 0.3632235838427755
#
#     index: 3
#     name: 60%~70%
#     prob: 0.5210084033613446
#     entropy: 0.33969180420268186
#
#     index: 4
#     name: >70%
#     prob: 0.12605042016806722
#     entropy: 0.2610596586566369
#
#
# name: Academic
# type: nominal
# num_cat: 5
# entropy: 1.2956486575013542
# std_entropy: 1.6094379124341003
# reliability: 0.8050317738208528
#
#     index: 0
#     name: <40%
#     prob: 0.019417475728155338
#     entropy: 0.07653556908096486
#
#     index: 1
#     name: 40%~49%
#     prob: 0.0970873786407767
#     entropy: 0.22642173740151358
#
#     index: 2
#     name: 50%~59%
#     prob: 0.33980582524271846
#     entropy: 0.3667799265622114
#
#     index: 3
#     name: 60%~70%
#     prob: 0.4174757281553398
#     entropy: 0.36467710212671023
#
#     index: 4
#     name: >70%
#     prob: 0.1262135922330097
#     entropy: 0.26123432232995425
#
#
# name: Attendance
# type: nominal
# num_cat: 5
# entropy: 1.2268593027293782
# std_entropy: 1.6094379124341003
# reliability: 0.7622905445752092
#
#     index: 0
#     name: S0
#     prob: 0.5294117647058824
#     entropy: 0.3366999353223512
#
#     index: 1
#     name: S1
#     prob: 0.25210084033613445
#     entropy: 0.34737633061748924
#
#     index: 2
#     name: S2
#     prob: 0.1092436974789916
#     entropy: 0.24188456944075548
#
#     index: 3
#     name: S3
#     prob: 0.08403361344537816
#     entropy: 0.2081124705981079
#
#     index: 4
#     name: S4
#     prob: 0.025210084033613446
#     entropy: 0.09278599675067445

# %% [markdown]
# # TEST FUNCTIONS

# %%
def test_prob(feat):
    for f in feat.keys():
        p = 0
        for cat in feat[f].categories.keys():
            p += feat[f].categories[cat].prob
        #assert(p == 1)#, 'Probability is not 1 for ' + f
        #print(p)
        assert(abs(1-p) <= 10**(-9) )
    return 'Test Probability Passed'

def test_entropy(feat):
    for f in feat.keys():
        for cat in feat[f].categories.keys():
            p = feat[f].categories[cat].prob
        assert(feat[f].categories[cat].entropy == -1*p*math.log(p)), 'Entropy is not -plog(p)'
    return 'Test Entropy Passed'

# %%
test_prob(feat)
# Out:
# 'Test Probability Passed'

# %%
test_entropy(feat)
# Out:
# 'Test Entropy Passed'
